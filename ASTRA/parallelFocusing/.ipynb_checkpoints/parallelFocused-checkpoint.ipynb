# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import os
import re
import yaml
import sys
import subprocess
import math

# %% [markdown]
# ## Parallel focusing
# function which looks for the best setup of magnets to focus beam with some input parameters (energy and other initial parameters) into a parallel focused beam. The setup of magnets consists of 3 permanent quadrupole magnets which are positioned one after another. Because they are permanent, the only varying parameters are the distances between them. Function RefParticles() runs only 5 reference particles, Beam() function runs the whole beam.

# %%
fileName = "parallelBeam"
fillNumber = "001"
setupLength = 4 #m
setupLengthStr = "0200"
longitudalEnergy = "5.0E+8" #eV


#parameters of magnets 
lengthQ1 = 0.036  #m
lengthQ2 = 0.12  #m
lengthQ3 = 0.1  #m

boreQ1 = 0.007
boreQ2 = 0.018
boreQ3 = 0.030

#offsets and angles for reference particles
xoffset = "2.0E-4" #m
yoffset =  "2.0E-4" #m
xmom = "1.0E+6" #eV
ymom = "1.0E+6" #eV


#input parameters of the beam
nParticles = "500"
sig_x=0.75E0  #gaussian distribution in x direction with this sigma
sig_y=0.75E0
sig_px = 0.075E0
sig_py = 0.075E0

# %%
dataD1 = []
dataD2 = []
dataD3 = []
dataMom = []
dataSumX = []
dataSumY = []

# %% [markdown]
# Files test0.ini all the way to test4.ini are input data for 5 different runs. File test0.ini has 0. reference particle with 0 offset and 0 initial angle, 1 and 2 have offsets in the x and y directions respectively and the last 2 have predefined angles. All of them should be parallel in the end.

# %%
def changeInputData(tag, newVar):
#universal function which changes input parameter in input file to Astra
    try:
        # Open the file for reading
        with open(fileName + ".in", 'r') as file:
            lines = file.readlines()

        # Prepare the replacement string
        replacement = " " + tag + "=" + newVar + "\n"

        # Iterate over the lines to find and replace the target line
        for i, line in enumerate(lines):
            if tag in line:
                lines[i] = replacement
                break  # Assuming there's only one occurrence to replace

        # Write the modified lines back to the file
        with open(fileName + ".in", 'w') as file:
            file.writelines(lines)

        #print(f"Replaced '{tag}' with '{replacement.strip()}'.")

    except FileNotFoundError:
        print("The file " + fileName + ".ini was not found.")
    except Exception as e:
        print(f"An error occurred when trying to change '{tag}' to variable '{newVar}': {e}")


    
    return

# %%
def topHatShapedQuads(ideal):
    #switcher between idealised quadrupoles without fringe fields or not
    if ideal:
        changeInputData("Q_bore{1}", "1E-9")
        changeInputData("Q_bore{2}", "1E-9")
        changeInputData("Q_bore{3}", "1E-9")
    else: 
        changeInputData("Q_bore{1}", str(boreQ1))
        changeInputData("Q_bore{2}", str(boreQ2))
        changeInputData("Q_bore{3}", str(boreQ3))

    return

# %%
def changeMomZ(momZ):
    try:
        testData = ""
        #change longitudinal momentum for files test0.ini through test4.ini and test.ini
        inputData0 = "  0.0000E+0  0.0000E+00  0.0000E+00  0.0000E+00  0.0000E+00  " + str(momZ) + "  0.0000E+00 -1.0000E-01   1   5"
        testData += inputData0 + "\n"
        with open("test0.ini", "w") as file:
            file.write(inputData0)
        
        inputData1 = "  " + xoffset + "  0.0000E+00  0.0000E+00  0.0000E+00  0.0000E+00  " + str(momZ) + "  0.0000E+00 -1.0000E-01   1   5"
        testData += inputData1 + "\n"
        with open("test1.ini", "w") as file:
            file.write(inputData1)
    
        inputData2 = "  0.0000E+00  " + yoffset + "  0.0000E+00  0.0000E+00  0.0000E+00  " + str(momZ) + "  0.0000E+00 -1.0000E-01   1   5"
        testData += inputData2 + "\n"
        with open("test2.ini", "w") as file:
            file.write(inputData2)
    
        inputData3 = "  0.0000E+00  0.0000E+00  0.0000E+00 " + xmom + " 0.0000E+00  " + str(momZ) + "  0.0000E+00 -1.0000E-01   1   5"
        testData += inputData3 + "\n"
        with open("test3.ini", "w") as file:
            file.write(inputData3)
    
        inputData4 = "  0.0000E+00  0.0000E+00  0.0000E+00  0.0000E+00 " + ymom + "  " + str(momZ) + "  0.0000E+00 -1.0000E-01   1   5"
        testData += inputData4 + "\n"    
        with open("test4.ini", "w") as file:
            file.write(inputData4)   
    
        with open("test.ini","w") as file:
            file.write(testData)
    
        #generate new data with new momentum
        changeInputData("Ref_Ekin", str(momZ))
        subprocess.run("./generator " + fileName + " > output.txt" , shell=True,check=True,executable='/bin/bash' )
        #print(f"Successfully changed momentum to files and ran a generation of particles saved to '{fileName}'.")

    except FileNotFoundError:
        print("One of the files when changing longitudinal momentum was not found.")
    except Exception as e:
        print(f"An error occurred when trying to change longitudinal momentum: {e}")

    return

# %%
def update():
    
    inputData = "  " + xoffset + "  0.0000E+00  0.0000E+00  0.0000E+00  0.0000E+00  5.0000E+08  0.0000E+00 -1.0000E-01   1   5"
    with open("test1.ini", "w") as file:
        file.write(inputData)

    inputData = "  0.0000E+00  " + yoffset + "  0.0000E+00  0.0000E+00  0.0000E+00  5.0000E+08  0.0000E+00 -1.0000E-01   1   5"
    with open("test2.ini", "w") as file:
        file.write(inputData)

    inputData = "  0.0000E+00  0.0000E+00  0.0000E+00 " + xmom + " 0.0000E+00  5.0000E+08  0.0000E+00 -1.0000E-01   1   5"
    with open("test3.ini", "w") as file:
        file.write(inputData)

    inputData = "  0.0000E+00  0.0000E+00  0.0000E+00  0.0000E+00 " + ymom + " 5.0000E+08  0.0000E+00 -1.0000E-01   1   5"
    with open("test4.ini", "w") as file:
        file.write(inputData)   

    #change input energy
    changeInputData("Ref_Ekin", longitudalEnergy)
    changeInputData("ZSTOP", str(setupLength) )

    #change properties of magnets
    changeInputData("Q_length(1)", str(lengthQ1))
    changeInputData("Q_length(2)", str(lengthQ2))
    changeInputData("Q_length(3)", str(lengthQ3))
    
    #change parameters of the beam
    changeInputData("IPart", str(nParticles))

    changeInputData("sig_x", str(sig_x))
    changeInputData("sig_y", str(sig_y))
    changeInputData("sig_px", str(sig_px))
    changeInputData("sig_py", str(sig_py))

    dataD1.clear()
    dataD2.clear()
    dataD3.clear()
    dataSumX.clear()
    dataSumY.clear()
    
    print(f"Succesfully updated all variables.")

    return

# %%
def isRef0Straight(px, py):
    #function which checks if 0. ref particle did not move
    if px == 0 and py == 0:
        return True
    else:
        return False

# %%
def differLine(line):
    lineSplitted = line.split()
    
    return [float(num) for num in lineSplitted]

# %%
def loadDataRef(arg):
#open and load data about reference particle
#z [m], t [ns], pz [MeV/c], dE/dz [MeV/c], Larmor Angle [rad], x off [mm], y off [mm], px [eV/c], py [eV/c]
    data = []
    #assuming setup length
    with open(fileName + "." + arg + "." + fillNumber,"r") as file:
        for line in file:
            newLine = differLine(line)
            data.append(newLine)

    return data

# %%
def runRef(D1, D2, D3,momZ, moreData):
    #this function runs Astra with 5 different reference particles for specific D1,D2,D3

    '''
    Q1pos = D1 + lengthQ1/2 + 3*boreQ1
    Q2pos = D1 + lengthQ1 + D2 + lengthQ2/2 + 6*boreQ1 + 3*boreQ2
    Q3pos = D1 + lengthQ1 + D2 + lengthQ2 + D3 + lengthQ3/2 + 6*boreQ1 + 6*boreQ2 + 3*boreQ3
    '''
    
    Q1pos = D1 + lengthQ1/2
    Q2pos = D1 + lengthQ1 + D2 + lengthQ2/2
    Q3pos = D1 + lengthQ1 + D2 + lengthQ2 + D3 + lengthQ3/2
    
    
    changeInputData("Q_pos(1)",str(Q1pos))
    changeInputData("Q_pos(2)",str(Q2pos) )
    changeInputData("Q_pos(3)",str(Q3pos) )
    changeMomZ(momZ)


    #if moreData, then provide tracking for each of the reference particles and return it for plotting
    if moreData:
        inputDataName = ["test0.ini", "test3.ini", "test4.ini"]
        outputMoreData = []
        for i in range(3):
            changeInputData("Distribution", inputDataName[i] )
            subprocess.run("source /opt/intel/oneapi/setvars.sh > out.txt && ./Astra " + fileName + " > output.txt", shell=True,check=True,executable='/bin/bash' )
            currentData = loadDataRef("ref")
            
            #condition for 0. ref particle-> it cannot move
            if i == 0 and not isRef0Straight(currentData[-1][7], currentData[-1][8]):
                print(f"Reference 0 particle with 0 offset and 0 angle moved in setup with D1 = '{D1}', D2 = '{D2}' and D3 = '{D3}'.")
                return 1
                
            #condition to check if the particle came all the way to the end
            distFromEnd = math.fabs(currentData[-1][0] - setupLength)
            if distFromEnd > 0.1:
                print(f"Reference particle '{i}' did not get to the end in setup with D1 = '{D1}', D2 = '{D2}' and D3 = '{D3}'. ")
                return 1
            
            outputMoreData.append(currentData)

        return outputMoreData
        
    else:
        inputDataName = ["test0.ini", "test3.ini", "test4.ini"]
        outputData = []
        for i in range(3):
            changeInputData("Distribution", inputDataName[i] )
            subprocess.run("source /opt/intel/oneapi/setvars.sh > out.txt && ./Astra " + fileName + " > output.txt", shell=True,check=True,executable='/bin/bash' )
            currentData = loadDataRef("ref")
            currentData = currentData[-1]
            #condition for 0. ref particle-> it cannot move
            if i == 0 and not isRef0Straight(currentData[7], currentData[8]):
                print(f"Reference 0 particle with 0 offset and 0 angle moved in setup with D1 = '{D1}', D2 = '{D2}' and D3 = '{D3}'.")
                return 1
            
            #condition to check if the particle came all the way to the end
            distFromEnd = math.fabs(currentData[0] - setupLength)
            if distFromEnd > 0.1:
                print(f"Reference particle '{i}' did not get to the end in setup with D1 = '{D1}', D2 = '{D2}' and D3 = '{D3}'. ")
                return 1

            #return data in format of input = [x,y,z,px, py, pz, t]
            
            currentData = [currentData[5]/1000, currentData[6]/1000, currentData[0], currentData[7], currentData[8], currentData[2]*1E+6, currentData[1] ]
            outputData.append(currentData)
        return outputData



    '''
    else:
        subprocess.run("source /opt/intel/oneapi/setvars.sh > out.txt && ./Astra " + fileName + " > output.txt", shell=True,check=True,executable='/bin/bash' )
        outputData = loadDataRef(setupLengthStr)
        
        #condition for 0. ref particle-> it cannot move
        if not isRef0Straight(outputData[0][3], outputData[0][4]):
            print(f"Reference 0. particle with 0 offset and 0 angle moved in setup with D1 = '{D1}', D2 = '{D2}' and D3 = '{D3}'.")
            return 1
                
        #condition to check if all particles came all the way to the end
        for j,row in enumerate(outputData):
            
            #z position for 1. particle, z positions of other particles relative to the 1. one
            distFromEnd = 0
            if j == 0:
                distFromEnd = math.fabs(outputData[j][2] - setupLength)
            else:
                distFromEnd = math.fabs(outputData[j][2] * outputData[0][2])
            if distFromEnd > 0.1:
                print(f"Reference particle '{j}' did not get to the end in setup with D1 = '{D1}', D2 = '{D2}' and D3 = '{D3}'. Distance from the end = '{distFromEnd}'. ")
                return 1  

        return outputData

    '''

# %%
def fill4DGraph(D1, D2,D3,mom,sumX, sumY):
    dataD1.append(D1)
    dataD2.append(D2)
    dataD3.append(D3)
    dataMom.append(mom)
    dataSumX.append(sumX)
    dataSumY.append(sumY)
    
    return

# %%
def angleCalculationX(data):
#calculate angle of particles in mrad and sum up x and y direction in squares
    
    sum =  data[1][3]**2 + data[2][4]**2
    return sum

# %%
def angleCalculationY(data):
#calculate angle of particles in mrad and sum up x and y direction in squares
    
    sum = (data[2][4])
    
    return sum

# %%
def giveRange(rangeVar, nInt):
    #function to determine whether a variable will be varied or not, if yes then determine the range
    output = []
    if rangeVar[0] != rangeVar[1]:
        interval =(rangeVar[1] - rangeVar[0])/nInt      
        for i in range(nInt):
            output.append(rangeVar[0] + i*interval)
    else:
        output.append(rangeVar[0])

    return output

# %%
def refParticles(D1_range, D2_range, D3_range, mom_range, nInt):

    update()
    
    D1 = giveRange(D1_range, nInt)
    D2 = giveRange(D2_range, nInt)
    D3 = giveRange(D3_range, nInt)
    mom = giveRange(mom_range, nInt)

    #test.ini file contains 5 reference particles
    changeInputData("Distribution", "test.ini" )


    bestSetupX = [0.5, 0.5, 0.5, 3E+8] 
    minSumX = 1e+9 #initial guess of sum of angles in x,y directions
    bestSetupY = [0.5, 0.5, 0.5, 3E+8] 
    minSumY = 1e+9 #initial guess of sum of angles in x,y directions
    
    #3 cycles which run through all ranges of D1, D2, D3
    for D1_current in D1:
        print(f"Running D1 = '{D1_current}'... ")
        for D2_current in D2:
            print(f"Running D2 = '{D2_current}'... ")
            for D3_current in D3:
                for mom_current in mom:
                    dataCurrent = runRef(D1_current, D2_current, D3_current, mom_current, False)
                    if dataCurrent == 1 or dataCurrent == None:
                         continue
                    
                    sumX = angleCalculationX(dataCurrent)
                    sumY = angleCalculationY(dataCurrent)
                    fill4DGraph(D1_current, D2_current, D3_current, mom_current, sumX, sumY)
                            
                    print(f"Angle sumX: '{sumX}', Angle sumY: '{sumY}' with D3 = '{D3_current}'.")

                    if math.fabs(sumX) <= minSumX:
                        minSumX = math.fabs(sumX)
                        bestSetupX = [D1_current, D2_current, D3_current, mom_current]
                    
                    if math.fabs(sumY) <= minSumY:
                        minSumY = math.fabs(sumY)
                        bestSetupY = [D1_current, D2_current, D3_current, mom_current]

                    #in case of finding the exact solution
                    if sumX == 0:
                        print(f"Found a solution for X!! Sum equals 0.")
                        bestSetupX = [D1_current, D2_current, D3_current, mom_current]
                        return bestSetupX, bestSetupY
                        
                    if sumY == 0:
                        print(f"Found a solution for Y!! Sum equals 0.")
                        bestSetupY = [D1_current, D2_current, D3_current, mom_current]
                        return bestSetupX, bestSetupY
                           
        print(f"finished it")
    
    print(f"Finished loop")   

    return bestSetupX, bestSetupY

# %%
def separateDataXYZ(data):

    z0 = []
    x0 = []
    y0 = []
    for element in data:
        z0.append(element[0])
        x0.append(element[5])
        y0.append(element[6])
        
    XYZ = []
    XYZ.append(x0)
    XYZ.append(y0)
    XYZ.append(z0)
    
    return XYZ

# %%
def plotRefXY(D1, D2, D3, mom):

    print(f"Running best setup again to get full data.")
    dataBest = runRef(D1, D2, D3, mom, True)

    data0 = separateDataXYZ(dataBest[0])
    #data1 = separateDataXYZ(dataBest[1])
    #data2 = separateDataXYZ(dataBest[2])
    data3 = separateDataXYZ(dataBest[1])
    data4 = separateDataXYZ(dataBest[2])


    plt.plot(data0[2], data0[0], label='0 offset, 0 angle', color='blue')
    #plt.plot(data1[2], data1[0], label='x offset, 0 angle', color='green')
    #plt.plot(data2[2], data2[0], label='y offset, 0 angle', color='red')
    plt.plot(data3[2], data3[0], label='0 offset, x angle', color='yellow')
    plt.plot(data4[2], data4[0], label='0 offset, y angle', color='purple')

    plt.legend()

    plt.xlabel("z [m]")
    plt.ylabel("x_offset [mm]")
    plt.title(f"x offset along z('{D1}', '{D2}', '{D3}')")

    plt.show()


    
    plt.plot(data0[2], data0[1], label='0 offset, 0 angle', color='blue')
    #plt.plot(data1[2], data1[1], label='x offset, 0 angle', color='green')
    #plt.plot(data2[2], data2[1], label='y offset, 0 angle', color='red')
    plt.plot(data3[2], data3[1], label='0 offset, x angle', color='yellow')
    plt.plot(data4[2], data4[1], label='0 offset, y angle', color='purple')

    plt.legend()

    plt.xlabel("z [m]")
    plt.ylabel("y_offset [mm]")
    plt.title(f"y offset along z('{D1}', '{D2}', '{D3}')")

    plt.show()
    
    return

# %%
def plot_4d_data(XorY):
    '''
    dataSum = []
    if XorY == "X":
        dataSum = dataSumX
    else:
        dataSum = dataSumY
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    # Scatter plot
    scatter = ax.scatter(dataD1, dataD2, dataD3, c=dataSum, cmap='viridis')
    
    # Add color bar to indicate the values of the 4th dimension
    color_bar = plt.colorbar(scatter, ax=ax, pad=0.1)
    color_bar.set_label('4th Dimension')
    
    # Labels and plot title
    ax.set_xlabel('D1 [m]')
    ax.set_ylabel('D2 [m]')
    ax.set_zlabel('D3 [m]')
    plt.title('function of angle sum for ' + XorY + ' focusing')
    
    plt.show()
    '''
    dataSum = []
    if XorY == "X":
        dataSum = dataSumX
    else:
        dataSum = dataSumY
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='2d')
    
    # Scatter plot
    scatter = ax.scatter(dataD2, dataD3, c=dataSum, cmap='viridis')
    
    # Add color bar to indicate the values of the 4th dimension
    color_bar = plt.colorbar(scatter, ax=ax, pad=0.1)
    color_bar.set_label('3rd Dimension')
    
    # Labels and plot title
    ax.set_xlabel('D1 [m]')
    ax.set_ylabel('D2 [m]')
    ax.set_zlabel("angle sum " + XorY)
    plt.title('function of angle sum for ' + XorY + ' focusing')
    
    plt.show()
    return

# %%
def plotDSum(whichData):

    dataD = []
    if whichData == "D1":
        dataD = dataD1
    elif whichData == "D2":
        dataD = dataD2
    elif whichData == "D3":
        dataD = dataD3
    else:
        dataD = dataMom
    
    plt.plot(dataD, dataSumX, label="X data direction", color='blue')
    plt.plot(dataD, dataSumY, label="y data direction", color='red')

    plt.legend()
    plt.xlabel(whichData + " [m]")
    plt.ylabel("sum [mrad]")
    plt.title(f"Function of varying '{whichData}'")
    plt.show()

    return

# %%
def plotSumData(XorY):

    dataSum = []
    if XorY == "X":
        dataSum = dataSumX
    else:
        dataSum = dataSumY
    
    
    plt.plot(dataSum, dataD1, label="D1", color='red')
    plt.plot(dataSum, dataD2, label="D2", color='blue')
    plt.plot(dataSum, dataD3, label="D3", color='green')

    plt.legend()
    plt.xlabel(" [m]")
    plt.ylabel("sum [mrad]")
    plt.title(f"Inverted function of D1, D2, D3 depending on dataSum'{XorY}' ")
    plt.show()

    return

# %%
#these are the ranges of variables through which the system will be running
#the first number is the lower, the second the top limit, if they are set to the same number, they will be constant
D1_range = [0.1,0.1]
D2_range = [0.,0.5] 
D3_range = [0.,0.5]
mom_range = [7.0E+8, 7.0E+8]
nIntervals = 50

topHatShapedQuads(True)

bestX, bestY = refParticles(D1_range,D2_range, D3_range, mom_range, nIntervals)

print(f"Best setup for focusing in the x direction: '{bestX}'. ")
print(f"Best setup for focusing in the y direction: '{bestY}'. ")

plotRefXY(*bestX) 
plotRefXY(*bestY)
# Out:
# Succesfully updated all variables.
# Running D1 = '0.1'...
# Running D2 = '0.0'...
# Angle sumX: '1719807105600.0', Angle sumY: '1098600.0' with D3 = '0.0'.
# Angle sumX: '1694465274100.0', Angle sumY: '1109500.0' with D3 = '0.01'.
# Angle sumX: '1670180112100.0', Angle sumY: '1118800.0' with D3 = '0.02'.
# Angle sumX: '1651131322400.0', Angle sumY: '1130500.0' with D3 = '0.03'.
# Angle sumX: '1632191380000.0', Angle sumY: '1139700.0' with D3 = '0.04'.
# Angle sumX: '1615582380100.0', Angle sumY: '1149000.0' with D3 = '0.05'.
# Angle sumX: '1603391371600.0', Angle sumY: '1159900.0' with D3 = '0.06'.
# Angle sumX: '1593152450000.0', Angle sumY: '1169900.0' with D3 = '0.07'.
# Angle sumX: '1584191848100.0', Angle sumY: '1179200.0' with D3 = '0.08'.
# Angle sumX: '1580163931600.0', Angle sumY: '1190200.0' with D3 = '0.09'.
# Angle sumX: '1578890784400.0', Angle sumY: '1201100.0' with D3 = '0.1'.
# Angle sumX: '1576008516100.0', Angle sumY: '1209400.0' with D3 = '0.11'.
# Angle sumX: '1579959100900.0', Angle sumY: '1220400.0' with D3 = '0.12'.
# Angle sumX: '1583429616400.0', Angle sumY: '1229600.0' with D3 = '0.13'.
# Angle sumX: '1591037050000.0', Angle sumY: '1239600.0' with D3 = '0.14'.
# Angle sumX: '1602998710400.0', Angle sumY: '1250600.0' with D3 = '0.15'.
# Angle sumX: '1613998600400.0', Angle sumY: '1259800.0' with D3 = '0.16'.
# Angle sumX: '1633622024900.0', Angle sumY: '1271800.0' with D3 = '0.17'.
# Angle sumX: '1649537990225.0', Angle sumY: '1280900.0' with D3 = '0.18'.
# Angle sumX: '1667774905641.0', Angle sumY: '1290000.0' with D3 = '0.19'.
# Angle sumX: '1693468586025.0', Angle sumY: '1301100.0' with D3 = '0.2'.
# Angle sumX: '1719073613965.61', Angle sumY: '1311100.0' with D3 = '0.21'.
# Angle sumX: '1744757911729.0', Angle sumY: '1320200.0' with D3 = '0.22'.
# Angle sumX: '1778576697104.0', Angle sumY: '1331300.0' with D3 = '0.23'.
# Angle sumX: '1815180089600.0', Angle sumY: '1342400.0' with D3 = '0.24'.
# Angle sumX: '1844945828900.0', Angle sumY: '1350400.0' with D3 = '0.25'.
# Angle sumX: '1887202435600.0', Angle sumY: '1361600.0' with D3 = '0.26'.
# Angle sumX: '1924963062500.0', Angle sumY: '1370600.0' with D3 = '0.27'.
# Angle sumX: '1968341544900.0', Angle sumY: '1380600.0' with D3 = '0.28'.
# Angle sumX: '2018806028900.0', Angle sumY: '1391800.0' with D3 = '0.29'.
# Angle sumX: '2063905962500.0', Angle sumY: '1400800.0' with D3 = '0.3'.
# Angle sumX: '2124079366100.0', Angle sumY: '1413100.0' with D3 = '0.31'.
# Angle sumX: '2173661848900.0', Angle sumY: '1422000.0' with D3 = '0.32'.
# Angle sumX: '2226056062500.0', Angle sumY: '1431000.0' with D3 = '0.33'.
# Angle sumX: '2290607458900.0', Angle sumY: '1442300.0' with D3 = '0.34'.
# Angle sumX: '2352046842400.0', Angle sumY: '1452300.0' with D3 = '0.35000000000000003'.
# Angle sumX: '2411402849600.0', Angle sumY: '1461200.0' with D3 = '0.36'.
# Angle sumX: '2484280115600.0', Angle sumY: '1472500.0' with D3 = '0.37'.
# Angle sumX: '2559436282100.0', Angle sumY: '1483700.0' with D3 = '0.38'.
# Angle sumX: '2619965281600.0', Angle sumY: '1491400.0' with D3 = '0.39'.
# Angle sumX: '2701197212500.0', Angle sumY: '1502700.0' with D3 = '0.4'.
# Angle sumX: '2772887712400.0', Angle sumY: '1511700.0' with D3 = '0.41000000000000003'.
# Angle sumX: '2851734913600.0', Angle sumY: '1521600.0' with D3 = '0.42'.
# Angle sumX: '2941665339600.0', Angle sumY: '1533000.0' with D3 = '0.43'.
# Angle sumX: '3020210568400.0', Angle sumY: '1541900.0' with D3 = '0.44'.
# Angle sumX: '3122498753600.0', Angle sumY: '1554400.0' with D3 = '0.45'.
# Angle sumX: '3205094809600.0', Angle sumY: '1563200.0' with D3 = '0.46'.
# Angle sumX: '3290740624400.0', Angle sumY: '1572100.0' with D3 = '0.47000000000000003'.
# Angle sumX: '3394481880400.0', Angle sumY: '1583400.0' with D3 = '0.48'.
# Angle sumX: '3491753336900.0', Angle sumY: '1593400.0' with D3 = '0.49'.
# Running D2 = '0.01'...
# Angle sumX: '1640819001600.0', Angle sumY: '1056000.0' with D3 = '0.0'.
# Angle sumX: '1608068426900.0', Angle sumY: '1063700.0' with D3 = '0.01'.
# Angle sumX: '1580213256400.0', Angle sumY: '1073800.0' with D3 = '0.02'.
# Angle sumX: '1553174740000.0', Angle sumY: '1081500.0' with D3 = '0.03'.
# Angle sumX: '1528265812900.0', Angle sumY: '1089200.0' with D3 = '0.04'.
# Angle sumX: '1507719362500.0', Angle sumY: '1098600.0' with D3 = '0.05'.
# Angle sumX: '1489182602500.0', Angle sumY: '1107000.0' with D3 = '0.06'.
# Angle sumX: '1472073736400.0', Angle sumY: '1114700.0' with D3 = '0.07'.
# Angle sumX: '1459592954100.0', Angle sumY: '1124100.0' with D3 = '0.08'.
# Angle sumX: '1449935384400.0', Angle sumY: '1133400.0' with D3 = '0.09'.
# Angle sumX: '1439513473600.0', Angle sumY: '1140200.0' with D3 = '0.1'.
# Angle sumX: '1435122201600.0', Angle sumY: '1149600.0' with D3 = '0.11'.
# Angle sumX: '1430940312500.0', Angle sumY: '1157300.0' with D3 = '0.12'.
# Angle sumX: '1430567974100.0', Angle sumY: '1165700.0' with D3 = '0.13'.
# Angle sumX: '1434557728400.0', Angle sumY: '1175200.0' with D3 = '0.14'.
# Angle sumX: '1437828780100.0', Angle sumY: '1182800.0' with D3 = '0.15'.
# Angle sumX: '1448867286100.0', Angle sumY: '1193100.0' with D3 = '0.16'.
# Angle sumX: '1457425720400.0', Angle sumY: '1200700.0' with D3 = '0.17'.
# Angle sumX: '1468336087769.0', Angle sumY: '1208300.0' with D3 = '0.18'.
# Angle sumX: '1486021386161.0', Angle sumY: '1217800.0' with D3 = '0.19'.
# Angle sumX: '1503955949696.0', Angle sumY: '1226200.0' with D3 = '0.2'.
# Angle sumX: '1522466444089.0', Angle sumY: '1233800.0' with D3 = '0.21'.
# Angle sumX: '1548407224321.0', Angle sumY: '1243300.0' with D3 = '0.22'.
# Angle sumX: '1577190537801.0', Angle sumY: '1252800.0' with D3 = '0.23'.
# Angle sumX: '1600219694900.0', Angle sumY: '1259300.0' with D3 = '0.24'.
# Angle sumX: '1634455362500.0', Angle sumY: '1268800.0' with D3 = '0.25'.
# Angle sumX: '1665567264100.0', Angle sumY: '1276400.0' with D3 = '0.26'.
# Angle sumX: '1701592864900.0', Angle sumY: '1284800.0' with D3 = '0.27'.
# Angle sumX: '1744430120000.0', Angle sumY: '1294400.0' with D3 = '0.28'.
# Angle sumX: '1782772859600.0', Angle sumY: '1301900.0' with D3 = '0.29'.
# Angle sumX: '1834854451600.0', Angle sumY: '1312500.0' with D3 = '0.3'.
# Angle sumX: '1877810365600.0', Angle sumY: '1319900.0' with D3 = '0.31'.
# Angle sumX: '1923594760000.0', Angle sumY: '1327400.0' with D3 = '0.32'.
# Angle sumX: '1980456856100.0', Angle sumY: '1337000.0' with D3 = '0.33'.
# Angle sumX: '2034853006400.0', Angle sumY: '1345400.0' with D3 = '0.34'.
# Angle sumX: '2088046932500.0', Angle sumY: '1352900.0' with D3 = '0.35000000000000003'.
# Angle sumX: '2153354954900.0', Angle sumY: '1362500.0' with D3 = '0.36'.
# Angle sumX: '2221289296400.0', Angle sumY: '1372100.0' with D3 = '0.37'.
# Angle sumX: '2276111184100.0', Angle sumY: '1378400.0' with D3 = '0.38'.
# Angle sumX: '2349915448900.0', Angle sumY: '1388000.0' with D3 = '0.39'.
# Angle sumX: '2415106606400.0', Angle sumY: '1395400.0' with D3 = '0.4'.
# Angle sumX: '2487809933600.0', Angle sumY: '1403900.0' with D3 = '0.41000000000000003'.
# Angle sumX: '2570421048100.0', Angle sumY: '1413600.0' with D3 = '0.42'.
# Angle sumX: '2642614488400.0', Angle sumY: '1420900.0' with D3 = '0.43'.
# Angle sumX: '2737673632900.0', Angle sumY: '1431800.0' with D3 = '0.44'.
# Angle sumX: '2814328675600.0', Angle sumY: '1439100.0' with D3 = '0.45'.
# Angle sumX: '2893760396900.0', Angle sumY: '1446400.0' with D3 = '0.46'.
# Angle sumX: '2991007440000.0', Angle sumY: '1456200.0' with D3 = '0.47000000000000003'.
# Angle sumX: '3081883570000.0', Angle sumY: '1464600.0' with D3 = '0.48'.
# Angle sumX: '3168490610000.0', Angle sumY: '1471900.0' with D3 = '0.49'.
# Running D2 = '0.02'...
# Angle sumX: '1562526072900.0', Angle sumY: '1009800.0' with D3 = '0.0'.
# Angle sumX: '1525815530000.0', Angle sumY: '1018300.0' with D3 = '0.01'.
# Angle sumX: '1490245864400.0', Angle sumY: '1024300.0' with D3 = '0.02'.
# Angle sumX: '1457050722500.0', Angle sumY: '1030400.0' with D3 = '0.03'.
# Angle sumX: '1427944462400.0', Angle sumY: '1038200.0' with D3 = '0.04'.
# Angle sumX: '1401172120100.0', Angle sumY: '1045000.0' with D3 = '0.05'.
# Angle sumX: '1375970942900.0', Angle sumY: '1051100.0' with D3 = '0.06'.
# Angle sumX: '1355109154900.0', Angle sumY: '1058900.0' with D3 = '0.07'.
# Angle sumX: '1337176450000.0', Angle sumY: '1066600.0' with D3 = '0.08'.
# Angle sumX: '1319084784100.0', Angle sumY: '1071800.0' with D3 = '0.09'.
# Angle sumX: '1306498862500.0', Angle sumY: '1079600.0' with D3 = '0.1'.
# Angle sumX: '1294358675600.0', Angle sumY: '1085600.0' with D3 = '0.11'.
# Angle sumX: '1286392246100.0', Angle sumY: '1092500.0' with D3 = '0.12'.
# Angle sumX: '1282125418900.0', Angle sumY: '1100300.0' with D3 = '0.13'.
# Angle sumX: '1277872272400.0', Angle sumY: '1106300.0' with D3 = '0.14'.
# Angle sumX: '1280795068900.0', Angle sumY: '1115000.0' with D3 = '0.15'.
# Angle sumX: '1281988824100.0', Angle sumY: '1121000.0' with D3 = '0.16'.
# Angle sumX: '1285579490000.0', Angle sumY: '1127000.0' with D3 = '0.17'.
# Angle sumX: '1295299899361.0', Angle sumY: '1134800.0' with D3 = '0.18'.
# Angle sumX: '1306089078100.0', Angle sumY: '1141700.0' with D3 = '0.19'.
# Angle sumX: '1317480263284.0', Angle sumY: '1147700.0' with D3 = '0.2'.
# Angle sumX: '1335636072500.0', Angle sumY: '1155500.0' with D3 = '0.21'.
# Angle sumX: '1356943254489.0', Angle sumY: '1163400.0' with D3 = '0.22'.
# Angle sumX: '1373341484564.0', Angle sumY: '1168300.0' with D3 = '0.23'.
# Angle sumX: '1400208920900.0', Angle sumY: '1176200.0' with D3 = '0.24'.
# Angle sumX: '1424532214400.0', Angle sumY: '1182200.0' with D3 = '0.25'.
# Angle sumX: '1453625057600.0', Angle sumY: '1189000.0' with D3 = '0.26'.
# Angle sumX: '1489018618100.0', Angle sumY: '1196900.0' with D3 = '0.27'.
# Angle sumX: '1521028589600.0', Angle sumY: '1202900.0' with D3 = '0.28'.
# Angle sumX: '1565522642500.0', Angle sumY: '1211800.0' with D3 = '0.29'.
# Angle sumX: '1602065164100.0', Angle sumY: '1217600.0' with D3 = '0.3'.
# Angle sumX: '1641473875600.0', Angle sumY: '1223500.0' with D3 = '0.31'.
# Angle sumX: '1691441672500.0', Angle sumY: '1231500.0' with D3 = '0.32'.
# Angle sumX: '1739348558900.0', Angle sumY: '1238300.0' with D3 = '0.33'.
# Angle sumX: '1786353352400.0', Angle sumY: '1244200.0' with D3 = '0.34'.
# Angle sumX: '1844964952900.0', Angle sumY: '1252200.0' with D3 = '0.35000000000000003'.
# Angle sumX: '1906015693600.0', Angle sumY: '1260100.0' with D3 = '0.36'.
# Angle sumX: '1955426450000.0', Angle sumY: '1264900.0' with D3 = '0.37'.
# Angle sumX: '2022712394400.0', Angle sumY: '1272900.0' with D3 = '0.38'.
# Angle sumX: '2082059534900.0', Angle sumY: '1278700.0' with D3 = '0.39'.
# Angle sumX: '2148679084100.0', Angle sumY: '1285600.0' with D3 = '0.4'.
# Angle sumX: '2224707210000.0', Angle sumY: '1293600.0' with D3 = '0.41000000000000003'.
# Angle sumX: '2291532388100.0', Angle sumY: '1299400.0' with D3 = '0.42'.
# Angle sumX: '2379546874900.0', Angle sumY: '1308500.0' with D3 = '0.43'.
# Angle sumX: '2450938874400.0', Angle sumY: '1314300.0' with D3 = '0.44'.
# Angle sumX: '2525198862100.0', Angle sumY: '1320100.0' with D3 = '0.45'.
# Angle sumX: '2616155003600.0', Angle sumY: '1328200.0' with D3 = '0.46'.
# Angle sumX: '2701407387600.0', Angle sumY: '1335000.0' with D3 = '0.47000000000000003'.
# Angle sumX: '2783058956900.0', Angle sumY: '1340800.0' with D3 = '0.48'.
# Angle sumX: '2882904650000.0', Angle sumY: '1348900.0' with D3 = '0.49'.
# Running D2 = '0.03'...
# Angle sumX: '1493709691700.0', Angle sumY: '969940.0' with D3 = '0.0'.
# Angle sumX: '1450572620900.0', Angle sumY: '974470.0' with D3 = '0.01'.
# Angle sumX: '1409700211600.0', Angle sumY: '979040.0' with D3 = '0.02'.
# Angle sumX: '1372636896500.0', Angle sumY: '985270.0' with D3 = '0.03'.
# Angle sumX: '1338346501700.0', Angle sumY: '990590.0' with D3 = '0.04'.
# Angle sumX: '1305653253200.0', Angle sumY: '995140.0' with D3 = '0.05'.
# Angle sumX: '1277053176100.0', Angle sumY: '1001400.0' with D3 = '0.06'.
# Angle sumX: '1251580136900.0', Angle sumY: '1007600.0' with D3 = '0.07'.
# Angle sumX: '1226305456400.0', Angle sumY: '1011200.0' with D3 = '0.08'.
# Angle sumX: '1206247152500.0', Angle sumY: '1017500.0' with D3 = '0.09'.
# Angle sumX: '1187080864400.0', Angle sumY: '1022000.0' with D3 = '0.1'.
# Angle sumX: '1171817328400.0', Angle sumY: '1027300.0' with D3 = '0.11'.
# Angle sumX: '1160265264100.0', Angle sumY: '1033600.0' with D3 = '0.12'.
# Angle sumX: '1149197160400.0', Angle sumY: '1038100.0' with D3 = '0.13'.
# Angle sumX: '1144768414100.0', Angle sumY: '1045300.0' with D3 = '0.14'.
# Angle sumX: '1139107510900.0', Angle sumY: '1049700.0' with D3 = '0.15'.
# Angle sumX: '1136093515600.0', Angle sumY: '1054200.0' with D3 = '0.16'.
# Angle sumX: '1138845060000.0', Angle sumY: '1060500.0' with D3 = '0.17'.
# Angle sumX: '1142773065625.0', Angle sumY: '1065800.0' with D3 = '0.18'.
# Angle sumX: '1147770118804.0', Angle sumY: '1070300.0' with D3 = '0.19'.
# Angle sumX: '1159146109223.84', Angle sumY: '1076600.0' with D3 = '0.2'.
# Angle sumX: '1173523590625.0', Angle sumY: '1082900.0' with D3 = '0.21'.
# Angle sumX: '1184226403600.0', Angle sumY: '1086400.0' with D3 = '0.22'.
# Angle sumX: '1204489744400.0', Angle sumY: '1092800.0' with D3 = '0.23'.
# Angle sumX: '1222542932900.0', Angle sumY: '1097200.0' with D3 = '0.24'.
# Angle sumX: '1245462936400.0', Angle sumY: '1102500.0' with D3 = '0.25'.
# Angle sumX: '1274442234400.0', Angle sumY: '1108900.0' with D3 = '0.26'.
# Angle sumX: '1300386624400.0', Angle sumY: '1113300.0' with D3 = '0.27'.
# Angle sumX: '1338119100100.0', Angle sumY: '1120600.0' with D3 = '0.28'.
# Angle sumX: '1369218859600.0', Angle sumY: '1125000.0' with D3 = '0.29'.
# Angle sumX: '1403007640400.0', Angle sumY: '1129400.0' with D3 = '0.3'.
# Angle sumX: '1446643872900.0', Angle sumY: '1135800.0' with D3 = '0.31'.
# Angle sumX: '1488828262100.0', Angle sumY: '1141100.0' with D3 = '0.32'.
# Angle sumX: '1530408715600.0', Angle sumY: '1145500.0' with D3 = '0.33'.
# Angle sumX: '1582879250900.0', Angle sumY: '1151900.0' with D3 = '0.34'.
# Angle sumX: '1638117360400.0', Angle sumY: '1158300.0' with D3 = '0.35000000000000003'.
# Angle sumX: '1682589850000.0', Angle sumY: '1161600.0' with D3 = '0.36'.
# Angle sumX: '1743938764100.0', Angle sumY: '1168000.0' with D3 = '0.37'.
# Angle sumX: '1798439948100.0', Angle sumY: '1172400.0' with D3 = '0.38'.
# Angle sumX: '1859551043600.0', Angle sumY: '1177700.0' with D3 = '0.39'.
# Angle sumX: '1929822412500.0', Angle sumY: '1184100.0' with D3 = '0.4'.
# Angle sumX: '1992003362900.0', Angle sumY: '1188500.0' with D3 = '0.41000000000000003'.
# Angle sumX: '2074117336100.0', Angle sumY: '1196000.0' with D3 = '0.42'.
# Angle sumX: '2140770246100.0', Angle sumY: '1200300.0' with D3 = '0.43'.
# Angle sumX: '2210364264400.0', Angle sumY: '1204600.0' with D3 = '0.44'.
# Angle sumX: '2295882723600.0', Angle sumY: '1211100.0' with D3 = '0.45'.
# Angle sumX: '2376324323600.0', Angle sumY: '1216400.0' with D3 = '0.46'.
# Angle sumX: '2453490000400.0', Angle sumY: '1220700.0' with D3 = '0.47000000000000003'.
# Angle sumX: '2548052480000.0', Angle sumY: '1227200.0' with D3 = '0.48'.
# Angle sumX: '2644945000000.0', Angle sumY: '1233600.0' with D3 = '0.49'.
# Running D2 = '0.04'...
# Angle sumX: '1425833438900.0', Angle sumY: '925670.0' with D3 = '0.0'.
# Angle sumX: '1377110976100.0', Angle sumY: '928650.0' with D3 = '0.01'.
# Angle sumX: '1332013501000.0', Angle sumY: '933310.0' with D3 = '0.02'.
# Angle sumX: '1290039002500.0', Angle sumY: '937080.0' with D3 = '0.03'.
# Angle sumX: '1249779505000.0', Angle sumY: '940050.0' with D3 = '0.04'.
# Angle sumX: '1213369046500.0', Angle sumY: '944730.0' with D3 = '0.05'.
# Angle sumX: '1180224693800.0', Angle sumY: '949370.0' with D3 = '0.06'.
# Angle sumX: '1147970978100.0', Angle sumY: '951450.0' with D3 = '0.07'.
# Angle sumX: '1120265223200.0', Angle sumY: '956140.0' with D3 = '0.08'.
# Angle sumX: '1094042997700.0', Angle sumY: '959090.0' with D3 = '0.09'.
# Angle sumX: '1071685395400.0', Angle sumY: '962850.0' with D3 = '0.1'.
# Angle sumX: '1052741105000.0', Angle sumY: '967550.0' with D3 = '0.11'.
# Angle sumX: '1034857541000.0', Angle sumY: '970490.0' with D3 = '0.12'.
# Angle sumX: '1022958846500.0', Angle sumY: '976070.0' with D3 = '0.13'.
# Angle sumX: '1010785363200.0', Angle sumY: '978960.0' with D3 = '0.14'.
# Angle sumX: '1001195028500.0', Angle sumY: '981890.0' with D3 = '0.15'.
# Angle sumX: '996989180200.0', Angle sumY: '986610.0' with D3 = '0.16'.
# Angle sumX: '994397997800.0', Angle sumY: '990370.0' with D3 = '0.17'.
# Angle sumX: '993055620581.0', Angle sumY: '993290.0' with D3 = '0.18'.
# Angle sumX: '997733130400.0', Angle sumY: '998020.0' with D3 = '0.19'.
# Angle sumX: '1005412646910.25', Angle sumY: '1002700.0' with D3 = '0.2'.
# Angle sumX: '1010458801204.0', Angle sumY: '1004700.0' with D3 = '0.21'.
# Angle sumX: '1023985177664.0', Angle sumY: '1009400.0' with D3 = '0.22'.
# Angle sumX: '1036307540000.0', Angle sumY: '1012300.0' with D3 = '0.23'.
# Angle sumX: '1053365478100.0', Angle sumY: '1016100.0' with D3 = '0.24'.
# Angle sumX: '1075844494400.0', Angle sumY: '1020800.0' with D3 = '0.25'.
# Angle sumX: '1096313302100.0', Angle sumY: '1023700.0' with D3 = '0.26'.
# Angle sumX: '1127670568400.0', Angle sumY: '1029400.0' with D3 = '0.27'.
# Angle sumX: '1153484394400.0', Angle sumY: '1032300.0' with D3 = '0.28'.
# Angle sumX: '1181842008400.0', Angle sumY: '1035100.0' with D3 = '0.29'.
# Angle sumX: '1219590072500.0', Angle sumY: '1039900.0' with D3 = '0.3'.
# Angle sumX: '1256484366900.0', Angle sumY: '1043700.0' with D3 = '0.31'.
# Angle sumX: '1292884765600.0', Angle sumY: '1046500.0' with D3 = '0.32'.
# Angle sumX: '1339720067600.0', Angle sumY: '1051300.0' with D3 = '0.33'.
# Angle sumX: '1389399460000.0', Angle sumY: '1056100.0' with D3 = '0.34'.
# Angle sumX: '1429457112500.0', Angle sumY: '1057900.0' with D3 = '0.35000000000000003'.
# Angle sumX: '1485417982900.0', Angle sumY: '1062700.0' with D3 = '0.36'.
# Angle sumX: '1535369882500.0', Angle sumY: '1065600.0' with D3 = '0.37'.
# Angle sumX: '1591552403600.0', Angle sumY: '1069300.0' with D3 = '0.38'.
# Angle sumX: '1656683818400.0', Angle sumY: '1074100.0' with D3 = '0.39'.
# Angle sumX: '1714566667600.0', Angle sumY: '1077000.0' with D3 = '0.4'.
# Angle sumX: '1791195400000.0', Angle sumY: '1082800.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1853734684100.0', Angle sumY: '1085600.0' with D3 = '0.42'.
# Angle sumX: '1919286396900.0', Angle sumY: '1088400.0' with D3 = '0.43'.
# Angle sumX: '1999838766400.0', Angle sumY: '1093200.0' with D3 = '0.44'.
# Angle sumX: '2076157324100.0', Angle sumY: '1097000.0' with D3 = '0.45'.
# Angle sumX: '2149529070400.0', Angle sumY: '1099800.0' with D3 = '0.46'.
# Angle sumX: '2239433320000.0', Angle sumY: '1104600.0' with D3 = '0.47000000000000003'.
# Angle sumX: '2331798850000.0', Angle sumY: '1109400.0' with D3 = '0.48'.
# Angle sumX: '2405273050000.0', Angle sumY: '1111200.0' with D3 = '0.49'.
# Running D2 = '0.05'...
# Angle sumX: '1359854896500.0', Angle sumY: '879060.0' with D3 = '0.0'.
# Angle sumX: '1306562919300.0', Angle sumY: '882120.0' with D3 = '0.01'.
# Angle sumX: '1256699678800.0', Angle sumY: '884280.0' with D3 = '0.02'.
# Angle sumX: '1208709886900.0', Angle sumY: '885620.0' with D3 = '0.03'.
# Angle sumX: '1164357344900.0', Angle sumY: '888680.0' with D3 = '0.04'.
# Angle sumX: '1123465554500.0', Angle sumY: '891730.0' with D3 = '0.05'.
# Angle sumX: '1083999841300.0', Angle sumY: '892180.0' with D3 = '0.06'.
# Angle sumX: '1048650571400.0', Angle sumY: '895250.0' with D3 = '0.07'.
# Angle sumX: '1015226217800.0', Angle sumY: '896570.0' with D3 = '0.08'.
# Angle sumX: '985733197600.0', Angle sumY: '898740.0' with D3 = '0.09'.
# Angle sumX: '959424956500.0', Angle sumY: '901820.0' with D3 = '0.1'.
# Angle sumX: '934668796900.0', Angle sumY: '903130.0' with D3 = '0.11'.
# Angle sumX: '915398586500.0', Angle sumY: '907090.0' with D3 = '0.12'.
# Angle sumX: '896656984400.0', Angle sumY: '908380.0' with D3 = '0.13'.
# Angle sumX: '880537144500.0', Angle sumY: '909690.0' with D3 = '0.14'.
# Angle sumX: '869430913300.0', Angle sumY: '912780.0' with D3 = '0.15'.
# Angle sumX: '860395852900.0', Angle sumY: '914950.0' with D3 = '0.16'.
# Angle sumX: '852840456100.0', Angle sumY: '916250.0' with D3 = '0.17'.
# Angle sumX: '850912376101.0', Angle sumY: '919350.0' with D3 = '0.18'.
# Angle sumX: '852171161629.0', Angle sumY: '922430.0' with D3 = '0.19'.
# Angle sumX: '851578740242.2736', Angle sumY: '922810.0' with D3 = '0.2'.
# Angle sumX: '858856177000.0', Angle sumY: '925910.0' with D3 = '0.21'.
# Angle sumX: '865530006856.0', Angle sumY: '927210.0' with D3 = '0.22'.
# Angle sumX: '876749689000.0', Angle sumY: '929370.0' with D3 = '0.23'.
# Angle sumX: '893299674500.0', Angle sumY: '932480.0' with D3 = '0.24'.
# Angle sumX: '908411233000.0', Angle sumY: '933770.0' with D3 = '0.25'.
# Angle sumX: '933604028200.0', Angle sumY: '937790.0' with D3 = '0.26'.
# Angle sumX: '954224330600.0', Angle sumY: '939050.0' with D3 = '0.27'.
# Angle sumX: '977709226500.0', Angle sumY: '940320.0' with D3 = '0.28'.
# Angle sumX: '1009855426100.0', Angle sumY: '943450.0' with D3 = '0.29'.
# Angle sumX: '1041618912500.0', Angle sumY: '945610.0' with D3 = '0.3'.
# Angle sumX: '1073452448000.0', Angle sumY: '946880.0' with D3 = '0.31'.
# Angle sumX: '1114993902600.0', Angle sumY: '950010.0' with D3 = '0.32'.
# Angle sumX: '1159458774800.0', Angle sumY: '953120.0' with D3 = '0.33'.
# Angle sumX: '1195636749200.0', Angle sumY: '953440.0' with D3 = '0.34'.
# Angle sumX: '1246625485300.0', Angle sumY: '956580.0' with D3 = '0.35000000000000003'.
# Angle sumX: '1292295283200.0', Angle sumY: '957840.0' with D3 = '0.36'.
# Angle sumX: '1344256014400.0', Angle sumY: '960000.0' with D3 = '0.37'.
# Angle sumX: '1404738226600.0', Angle sumY: '963150.0' with D3 = '0.38'.
# Angle sumX: '1458625440400.0', Angle sumY: '964400.0' with D3 = '0.39'.
# Angle sumX: '1530391600400.0', Angle sumY: '968480.0' with D3 = '0.4'.
# Angle sumX: '1589312732200.0', Angle sumY: '969710.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1651373725700.0', Angle sumY: '970960.0' with D3 = '0.42'.
# Angle sumX: '1727802445700.0', Angle sumY: '974110.0' with D3 = '0.43'.
# Angle sumX: '1800387659300.0', Angle sumY: '976280.0' with D3 = '0.44'.
# Angle sumX: '1870571515300.0', Angle sumY: '977520.0' with D3 = '0.45'.
# Angle sumX: '1956619816000.0', Angle sumY: '980680.0' with D3 = '0.46'.
# Angle sumX: '2045345792400.0', Angle sumY: '983820.0' with D3 = '0.47000000000000003'.
# Angle sumX: '2116077454900.0', Angle sumY: '984070.0' with D3 = '0.48'.
# Angle sumX: '2211854107600.0', Angle sumY: '987240.0' with D3 = '0.49'.
# Running D2 = '0.06'...
# Angle sumX: '1300976808500.0', Angle sumY: '837370.0' with D3 = '0.0'.
# Angle sumX: '1243689788900.0', Angle sumY: '838000.0' with D3 = '0.01'.
# Angle sumX: '1188362017700.0', Angle sumY: '837760.0' with D3 = '0.02'.
# Angle sumX: '1136552530500.0', Angle sumY: '839280.0' with D3 = '0.03'.
# Angle sumX: '1088332880500.0', Angle sumY: '840790.0' with D3 = '0.04'.
# Angle sumX: '1042072400500.0', Angle sumY: '839670.0' with D3 = '0.05'.
# Angle sumX: '999518688500.0', Angle sumY: '841180.0' with D3 = '0.06'.
# Angle sumX: '959354792500.0', Angle sumY: '840940.0' with D3 = '0.07'.
# Angle sumX: '923137209800.0', Angle sumY: '841570.0' with D3 = '0.08'.
# Angle sumX: '889932845700.0', Angle sumY: '843090.0' with D3 = '0.09'.
# Angle sumX: '858775162500.0', Angle sumY: '842850.0' with D3 = '0.1'.
# Angle sumX: '832625375400.0', Angle sumY: '845250.0' with D3 = '0.11'.
# Angle sumX: '807758945600.0', Angle sumY: '845000.0' with D3 = '0.12'.
# Angle sumX: '785555260100.0', Angle sumY: '844750.0' with D3 = '0.13'.
# Angle sumX: '768046236800.0', Angle sumY: '846280.0' with D3 = '0.14'.
# Angle sumX: '752994638100.0', Angle sumY: '846900.0' with D3 = '0.15'.
# Angle sumX: '739715768500.0', Angle sumY: '846660.0' with D3 = '0.16'.
# Angle sumX: '731652734900.0', Angle sumY: '848180.0' with D3 = '0.17'.
# Angle sumX: '726938086964.0', Angle sumY: '849700.0' with D3 = '0.18'.
# Angle sumX: '721230563600.0', Angle sumY: '848560.0' with D3 = '0.19'.
# Angle sumX: '722694350428.04', Angle sumY: '850090.0' with D3 = '0.2'.
# Angle sumX: '724170102361.0', Angle sumY: '849840.0' with D3 = '0.21'.
# Angle sumX: '730116209824.0', Angle sumY: '850460.0' with D3 = '0.22'.
# Angle sumX: '741139210100.0', Angle sumY: '851990.0' with D3 = '0.23'.
# Angle sumX: '751394909200.0', Angle sumY: '851740.0' with D3 = '0.24'.
# Angle sumX: '770989346500.0', Angle sumY: '854160.0' with D3 = '0.25'.
# Angle sumX: '787023946400.0', Angle sumY: '853900.0' with D3 = '0.26'.
# Angle sumX: '806002322500.0', Angle sumY: '853650.0' with D3 = '0.27'.
# Angle sumX: '833106592800.0', Angle sumY: '855180.0' with D3 = '0.28'.
# Angle sumX: '860324278600.0', Angle sumY: '855810.0' with D3 = '0.29'.
# Angle sumX: '887967103400.0', Angle sumY: '855550.0' with D3 = '0.3'.
# Angle sumX: '924786478100.0', Angle sumY: '857090.0' with D3 = '0.31'.
# Angle sumX: '964661914400.0', Angle sumY: '858620.0' with D3 = '0.32'.
# Angle sumX: '997303066100.0', Angle sumY: '857450.0' with D3 = '0.33'.
# Angle sumX: '1043860869000.0', Angle sumY: '858990.0' with D3 = '0.34'.
# Angle sumX: '1085883109000.0', Angle sumY: '858730.0' with D3 = '0.35000000000000003'.
# Angle sumX: '1134027397700.0', Angle sumY: '859360.0' with D3 = '0.36'.
# Angle sumX: '1190383872500.0', Angle sumY: '860900.0' with D3 = '0.37'.
# Angle sumX: '1240928995300.0', Angle sumY: '860630.0' with D3 = '0.38'.
# Angle sumX: '1308472590500.0', Angle sumY: '863080.0' with D3 = '0.39'.
# Angle sumX: '1364296622400.0', Angle sumY: '862800.0' with D3 = '0.4'.
# Angle sumX: '1423346829200.0', Angle sumY: '862540.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1496174624000.0', Angle sumY: '864080.0' with D3 = '0.42'.
# Angle sumX: '1565644656200.0', Angle sumY: '864710.0' with D3 = '0.43'.
# Angle sumX: '1633132777700.0', Angle sumY: '864440.0' with D3 = '0.44'.
# Angle sumX: '1715913145700.0', Angle sumY: '865990.0' with D3 = '0.45'.
# Angle sumX: '1801389110900.0', Angle sumY: '867530.0' with D3 = '0.46'.
# Angle sumX: '1870349562500.0', Angle sumY: '866350.0' with D3 = '0.47000000000000003'.
# Angle sumX: '1963030420000.0', Angle sumY: '867900.0' with D3 = '0.48'.
# Angle sumX: '2044396714400.0', Angle sumY: '867620.0' with D3 = '0.49'.
# Running D2 = '0.07'...
# Angle sumX: '1246579710500.0', Angle sumY: '795370.0' with D3 = '0.0'.
# Angle sumX: '1184033594900.0', Angle sumY: '793570.0' with D3 = '0.01'.
# Angle sumX: '1124904813800.0', Angle sumY: '793570.0' with D3 = '0.02'.
# Angle sumX: '1069518659200.0', Angle sumY: '793560.0' with D3 = '0.03'.
# Angle sumX: '1016578811300.0', Angle sumY: '790880.0' with D3 = '0.04'.
# Angle sumX: '967022093300.0', Angle sumY: '790870.0' with D3 = '0.05'.
# Angle sumX: '920256267400.0', Angle sumY: '789070.0' with D3 = '0.06'.
# Angle sumX: '877496525300.0', Angle sumY: '788180.0' with D3 = '0.07'.
# Angle sumX: '837604381300.0', Angle sumY: '788170.0' with D3 = '0.08'.
# Angle sumX: '800211793300.0', Angle sumY: '786370.0' with D3 = '0.09'.
# Angle sumX: '767433680900.0', Angle sumY: '787250.0' with D3 = '0.1'.
# Angle sumX: '736637604500.0', Angle sumY: '785470.0' with D3 = '0.11'.
# Angle sumX: '708575340800.0', Angle sumY: '783680.0' with D3 = '0.12'.
# Angle sumX: '684905598100.0', Angle sumY: '783660.0' with D3 = '0.13'.
# Angle sumX: '664121762900.0', Angle sumY: '782770.0' with D3 = '0.14'.
# Angle sumX: '645330182900.0', Angle sumY: '780980.0' with D3 = '0.15'.
# Angle sumX: '631451697700.0', Angle sumY: '780960.0' with D3 = '0.16'.
# Angle sumX: '621058807700.0', Angle sumY: '780940.0' with D3 = '0.17'.
# Angle sumX: '610483518800.0', Angle sumY: '778280.0' with D3 = '0.18'.
# Angle sumX: '606448622224.0', Angle sumY: '778260.0' with D3 = '0.19'.
# Angle sumX: '603037808801.0', Angle sumY: '776480.0' with D3 = '0.2'.
# Angle sumX: '604051060644.0', Angle sumY: '775590.0' with D3 = '0.21'.
# Angle sumX: '609897435876.0', Angle sumY: '775560.0' with D3 = '0.22'.
# Angle sumX: '615617293300.0', Angle sumY: '773780.0' with D3 = '0.23'.
# Angle sumX: '630011785000.0', Angle sumY: '774630.0' with D3 = '0.24'.
# Angle sumX: '641795607700.0', Angle sumY: '772860.0' with D3 = '0.25'.
# Angle sumX: '656595250000.0', Angle sumY: '771080.0' with D3 = '0.26'.
# Angle sumX: '679088558600.0', Angle sumY: '771050.0' with D3 = '0.27'.
# Angle sumX: '702152051200.0', Angle sumY: '770160.0' with D3 = '0.28'.
# Angle sumX: '725979064400.0', Angle sumY: '768380.0' with D3 = '0.29'.
# Angle sumX: '758502725000.0', Angle sumY: '768350.0' with D3 = '0.3'.
# Angle sumX: '794240118800.0', Angle sumY: '768320.0' with D3 = '0.31'.
# Angle sumX: '823771705000.0', Angle sumY: '765690.0' with D3 = '0.32'.
# Angle sumX: '866367826600.0', Angle sumY: '765650.0' with D3 = '0.33'.
# Angle sumX: '905171776900.0', Angle sumY: '763880.0' with D3 = '0.34'.
# Angle sumX: '949947471700.0', Angle sumY: '762990.0' with D3 = '0.35000000000000003'.
# Angle sumX: '1002683863400.0', Angle sumY: '762950.0' with D3 = '0.36'.
# Angle sumX: '1050375230800.0', Angle sumY: '761180.0' with D3 = '0.37'.
# Angle sumX: '1114215811600.0', Angle sumY: '762000.0' with D3 = '0.38'.
# Angle sumX: '1167450835400.0', Angle sumY: '760250.0' with D3 = '0.39'.
# Angle sumX: '1223992348200.0', Angle sumY: '758490.0' with D3 = '0.4'.
# Angle sumX: '1293758709200.0', Angle sumY: '758440.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1360668742600.0', Angle sumY: '757550.0' with D3 = '0.42'.
# Angle sumX: '1425992735700.0', Angle sumY: '755790.0' with D3 = '0.43'.
# Angle sumX: '1506038557600.0', Angle sumY: '755740.0' with D3 = '0.44'.
# Angle sumX: '1588961700000.0', Angle sumY: '755700.0' with D3 = '0.45'.
# Angle sumX: '1656454238100.0', Angle sumY: '753090.0' with D3 = '0.46'.
# Angle sumX: '1746682451600.0', Angle sumY: '753040.0' with D3 = '0.47000000000000003'.
# Angle sumX: '1826688914100.0', Angle sumY: '751290.0' with D3 = '0.48'.
# Angle sumX: '1915204000000.0', Angle sumY: '750400.0' with D3 = '0.49'.
# Running D2 = '0.08'...
# Angle sumX: '1193149352000.0', Angle sumY: '748360.0' with D3 = '0.0'.
# Angle sumX: '1126227111200.0', Angle sumY: '746740.0' with D3 = '0.01'.
# Angle sumX: '1063274692500.0', Angle sumY: '745140.0' with D3 = '0.02'.
# Angle sumX: '1003262862500.0', Angle sumY: '740800.0' with D3 = '0.03'.
# Angle sumX: '946329480500.0', Angle sumY: '739180.0' with D3 = '0.04'.
# Angle sumX: '892630346000.0', Angle sumY: '735740.0' with D3 = '0.05'.
# Angle sumX: '843033374600.0', Angle sumY: '733250.0' with D3 = '0.06'.
# Angle sumX: '796139185000.0', Angle sumY: '731610.0' with D3 = '0.07'.
# Angle sumX: '752266128500.0', Angle sumY: '728180.0' with D3 = '0.08'.
# Angle sumX: '712590130100.0', Angle sumY: '727450.0' with D3 = '0.09'.
# Angle sumX: '675662776900.0', Angle sumY: '724050.0' with D3 = '0.1'.
# Angle sumX: '641562719400.0', Angle sumY: '720630.0' with D3 = '0.11'.
# Angle sumX: '611562304800.0', Angle sumY: '718980.0' with D3 = '0.12'.
# Angle sumX: '584889140800.0', Angle sumY: '716480.0' with D3 = '0.13'.
# Angle sumX: '560507559300.0', Angle sumY: '713070.0' with D3 = '0.14'.
# Angle sumX: '540706976800.0', Angle sumY: '711420.0' with D3 = '0.15'.
# Angle sumX: '524572637300.0', Angle sumY: '709780.0' with D3 = '0.16'.
# Angle sumX: '509119898500.0', Angle sumY: '705520.0' with D3 = '0.17'.
# Angle sumX: '499543686056.0', Angle sumY: '703850.0' with D3 = '0.18'.
# Angle sumX: '491263278421.0', Angle sumY: '700450.0' with D3 = '0.19'.
# Angle sumX: '487371514625.0', Angle sumY: '697960.0' with D3 = '0.2'.
# Angle sumX: '488104314821.0', Angle sumY: '696290.0' with D3 = '0.21'.
# Angle sumX: '489397972384.0', Angle sumY: '692900.0' with D3 = '0.22'.
# Angle sumX: '498683883700.0', Angle sumY: '692090.0' with D3 = '0.23'.
# Angle sumX: '506361920000.0', Angle sumY: '688720.0' with D3 = '0.24'.
# Angle sumX: '517175683700.0', Angle sumY: '685340.0' with D3 = '0.25'.
# Angle sumX: '535216734100.0', Angle sumY: '683650.0' with D3 = '0.26'.
# Angle sumX: '554339305600.0', Angle sumY: '681160.0' with D3 = '0.27'.
# Angle sumX: '574605242000.0', Angle sumY: '677780.0' with D3 = '0.28'.
# Angle sumX: '603098098100.0', Angle sumY: '676090.0' with D3 = '0.29'.
# Angle sumX: '634983161300.0', Angle sumY: '674420.0' with D3 = '0.3'.
# Angle sumX: '661701593800.0', Angle sumY: '670230.0' with D3 = '0.31'.
# Angle sumX: '700696423400.0', Angle sumY: '668530.0' with D3 = '0.32'.
# Angle sumX: '736635585600.0', Angle sumY: '665160.0' with D3 = '0.33'.
# Angle sumX: '778437778900.0', Angle sumY: '662670.0' with D3 = '0.34'.
# Angle sumX: '827980773700.0', Angle sumY: '660960.0' with D3 = '0.35000000000000003'.
# Angle sumX: '873253957000.0', Angle sumY: '657610.0' with D3 = '0.36'.
# Angle sumX: '933877082000.0', Angle sumY: '656720.0' with D3 = '0.37'.
# Angle sumX: '984985380900.0', Angle sumY: '653400.0' with D3 = '0.38'.
# Angle sumX: '1039512414100.0', Angle sumY: '650050.0' with D3 = '0.39'.
# Angle sumX: '1106810320500.0', Angle sumY: '648330.0' with D3 = '0.4'.
# Angle sumX: '1171701331300.0', Angle sumY: '645830.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1235455250000.0', Angle sumY: '642500.0' with D3 = '0.42'.
# Angle sumX: '1313415410000.0', Angle sumY: '640760.0' with D3 = '0.43'.
# Angle sumX: '1394493483400.0', Angle sumY: '639050.0' with D3 = '0.44'.
# Angle sumX: '1460961053600.0', Angle sumY: '634940.0' with D3 = '0.45'.
# Angle sumX: '1549697480000.0', Angle sumY: '633200.0' with D3 = '0.46'.
# Angle sumX: '1628848814400.0', Angle sumY: '629880.0' with D3 = '0.47000000000000003'.
# Angle sumX: '1716335674400.0', Angle sumY: '627380.0' with D3 = '0.48'.
# Angle sumX: '1815855146900.0', Angle sumY: '625630.0' with D3 = '0.49'.
# Running D2 = '0.09'...
# Angle sumX: '1145755760500.0', Angle sumY: '706890.0' with D3 = '0.0'.
# Angle sumX: '1075600981300.0', Angle sumY: '703770.0' with D3 = '0.01'.
# Angle sumX: '1008842425600.0', Angle sumY: '697840.0' with D3 = '0.02'.
# Angle sumX: '944912304900.0', Angle sumY: '694680.0' with D3 = '0.03'.
# Angle sumX: '884617749000.0', Angle sumY: '689670.0' with D3 = '0.04'.
# Angle sumX: '828519952000.0', Angle sumY: '685640.0' with D3 = '0.05'.
# Angle sumX: '775021106000.0', Angle sumY: '682460.0' with D3 = '0.06'.
# Angle sumX: '725004925000.0', Angle sumY: '677470.0' with D3 = '0.07'.
# Angle sumX: '678830105600.0', Angle sumY: '675200.0' with D3 = '0.08'.
# Angle sumX: '636109706600.0', Angle sumY: '670250.0' with D3 = '0.09'.
# Angle sumX: '596289752500.0', Angle sumY: '665260.0' with D3 = '0.1'.
# Angle sumX: '560347906000.0', Angle sumY: '662060.0' with D3 = '0.11'.
# Angle sumX: '528151052500.0', Angle sumY: '658030.0' with D3 = '0.12'.
# Angle sumX: '498504453200.0', Angle sumY: '653060.0' with D3 = '0.13'.
# Angle sumX: '473150762600.0', Angle sumY: '649850.0' with D3 = '0.14'.
# Angle sumX: '451656450500.0', Angle sumY: '646670.0' with D3 = '0.15'.
# Angle sumX: '431622269200.0', Angle sumY: '640860.0' with D3 = '0.16'.
# Angle sumX: '416906772500.0', Angle sumY: '637630.0' with D3 = '0.17'.
# Angle sumX: '404096797904.0', Angle sumY: '632680.0' with D3 = '0.18'.
# Angle sumX: '395651125684.0', Angle sumY: '628660.0' with D3 = '0.19'.
# Angle sumX: '391641773984.0', Angle sumY: '625420.0' with D3 = '0.2'.
# Angle sumX: '388835587361.0', Angle sumY: '620480.0' with D3 = '0.21'.
# Angle sumX: '393423965600.0', Angle sumY: '618100.0' with D3 = '0.22'.
# Angle sumX: '397330240000.0', Angle sumY: '613200.0' with D3 = '0.23'.
# Angle sumX: '404485334500.0', Angle sumY: '608280.0' with D3 = '0.24'.
# Angle sumX: '418476461300.0', Angle sumY: '605020.0' with D3 = '0.25'.
# Angle sumX: '433997209000.0', Angle sumY: '600990.0' with D3 = '0.26'.
# Angle sumX: '451039726400.0', Angle sumY: '596080.0' with D3 = '0.27'.
# Angle sumX: '475891536100.0', Angle sumY: '592810.0' with D3 = '0.28'.
# Angle sumX: '504286133200.0', Angle sumY: '589560.0' with D3 = '0.29'.
# Angle sumX: '528508788800.0', Angle sumY: '583880.0' with D3 = '0.3'.
# Angle sumX: '564260905000.0', Angle sumY: '580590.0' with D3 = '0.31'.
# Angle sumX: '597696810100.0', Angle sumY: '575700.0' with D3 = '0.32'.
# Angle sumX: '636888808000.0', Angle sumY: '571680.0' with D3 = '0.33'.
# Angle sumX: '683608036000.0', Angle sumY: '568380.0' with D3 = '0.34'.
# Angle sumX: '726786722900.0', Angle sumY: '563500.0' with D3 = '0.35000000000000003'.
# Angle sumX: '784592610500.0', Angle sumY: '560990.0' with D3 = '0.36'.
# Angle sumX: '833909949700.0', Angle sumY: '556160.0' with D3 = '0.37'.
# Angle sumX: '886787592500.0', Angle sumY: '551300.0' with D3 = '0.38'.
# Angle sumX: '951950788000.0', Angle sumY: '547980.0' with D3 = '0.39'.
# Angle sumX: '1015206099400.0', Angle sumY: '543950.0' with D3 = '0.4'.
# Angle sumX: '1077699418900.0', Angle sumY: '539100.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1153967365700.0', Angle sumY: '535760.0' with D3 = '0.42'.
# Angle sumX: '1233514754000.0', Angle sumY: '532460.0' with D3 = '0.43'.
# Angle sumX: '1299542420000.0', Angle sumY: '526900.0' with D3 = '0.44'.
# Angle sumX: '1386918612500.0', Angle sumY: '523550.0' with D3 = '0.45'.
# Angle sumX: '1465468878400.0', Angle sumY: '518720.0' with D3 = '0.46'.
# Angle sumX: '1552222956100.0', Angle sumY: '514690.0' with D3 = '0.47000000000000003'.
# Angle sumX: '1651027808900.0', Angle sumY: '511330.0' with D3 = '0.48'.
# Angle sumX: '1738868760400.0', Angle sumY: '506520.0' with D3 = '0.49'.
# Running D2 = '0.1'...
# Angle sumX: '1102426210100.0', Angle sumY: '666010.0' with D3 = '0.0'.
# Angle sumX: '1028927083600.0', Angle sumY: '658500.0' with D3 = '0.01'.
# Angle sumX: '958047152400.0', Angle sumY: '653820.0' with D3 = '0.02'.
# Angle sumX: '891203890900.0', Angle sumY: '647250.0' with D3 = '0.03'.
# Angle sumX: '828694466100.0', Angle sumY: '641700.0' with D3 = '0.04'.
# Angle sumX: '768679548200.0', Angle sumY: '637010.0' with D3 = '0.05'.
# Angle sumX: '712581025000.0', Angle sumY: '630450.0' with D3 = '0.06'.
# Angle sumX: '660047843300.0', Angle sumY: '626680.0' with D3 = '0.07'.
# Angle sumX: '611611652500.0', Angle sumY: '620190.0' with D3 = '0.08'.
# Angle sumX: '566212716500.0', Angle sumY: '613660.0' with D3 = '0.09'.
# Angle sumX: '524467585000.0', Angle sumY: '608930.0' with D3 = '0.1'.
# Angle sumX: '486868609300.0', Angle sumY: '603380.0' with D3 = '0.11'.
# Angle sumX: '452094019600.0', Angle sumY: '596860.0' with D3 = '0.12'.
# Angle sumX: '421372734800.0', Angle sumY: '592120.0' with D3 = '0.13'.
# Angle sumX: '394681436500.0', Angle sumY: '587410.0' with D3 = '0.14'.
# Angle sumX: '370234243300.0', Angle sumY: '580070.0' with D3 = '0.15'.
# Angle sumX: '350589997000.0', Angle sumY: '575310.0' with D3 = '0.16'.
# Angle sumX: '333433968169.0', Angle sumY: '568820.0' with D3 = '0.17'.
# Angle sumX: '320630749504.0', Angle sumY: '563280.0' with D3 = '0.18'.
# Angle sumX: '312108089396.0', Angle sumY: '558490.0' with D3 = '0.19'.
# Angle sumX: '305438788021.0', Angle sumY: '552030.0' with D3 = '0.2'.
# Angle sumX: '305570532644.0', Angle sumY: '548090.0' with D3 = '0.21'.
# Angle sumX: '305950024900.0', Angle sumY: '541680.0' with D3 = '0.22'.
# Angle sumX: '309684722500.0', Angle sumY: '535230.0' with D3 = '0.23'.
# Angle sumX: '319906553300.0', Angle sumY: '530420.0' with D3 = '0.24'.
# Angle sumX: '332108719400.0', Angle sumY: '524870.0' with D3 = '0.25'.
# Angle sumX: '346197531200.0', Angle sumY: '518440.0' with D3 = '0.26'.
# Angle sumX: '367711201700.0', Angle sumY: '513610.0' with D3 = '0.27'.
# Angle sumX: '392956292000.0', Angle sumY: '508820.0' with D3 = '0.28'.
# Angle sumX: '414947581700.0', Angle sumY: '501640.0' with D3 = '0.29'.
# Angle sumX: '447818026600.0', Angle sumY: '496790.0' with D3 = '0.3'.
# Angle sumX: '479065754600.0', Angle sumY: '490390.0' with D3 = '0.31'.
# Angle sumX: '515968922600.0', Angle sumY: '484850.0' with D3 = '0.32'.
# Angle sumX: '560247236000.0', Angle sumY: '479980.0' with D3 = '0.33'.
# Angle sumX: '601698308900.0', Angle sumY: '473600.0' with D3 = '0.34'.
# Angle sumX: '657077500100.0', Angle sumY: '469490.0' with D3 = '0.35000000000000003'.
# Angle sumX: '704988557800.0', Angle sumY: '463170.0' with D3 = '0.36'.
# Angle sumX: '756562280000.0', Angle sumY: '456800.0' with D3 = '0.37'.
# Angle sumX: '820055210600.0', Angle sumY: '451910.0' with D3 = '0.38'.
# Angle sumX: '882041992000.0', Angle sumY: '446360.0' with D3 = '0.39'.
# Angle sumX: '943703366500.0', Angle sumY: '440010.0' with D3 = '0.4'.
# Angle sumX: '1018750655700.0', Angle sumY: '435090.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1097209750900.0', Angle sumY: '430220.0' with D3 = '0.42'.
# Angle sumX: '1163079970900.0', Angle sumY: '423220.0' with D3 = '0.43'.
# Angle sumX: '1249705048400.0', Angle sumY: '418280.0' with D3 = '0.44'.
# Angle sumX: '1328132731600.0', Angle sumY: '411960.0' with D3 = '0.45'.
# Angle sumX: '1414654056400.0', Angle sumY: '406420.0' with D3 = '0.46'.
# Angle sumX: '1513049450900.0', Angle sumY: '401470.0' with D3 = '0.47000000000000003'.
# Angle sumX: '1601444168900.0', Angle sumY: '395170.0' with D3 = '0.48'.
# Angle sumX: '1714545082100.0', Angle sumY: '390890.0' with D3 = '0.49'.
# Running D2 = '0.11'...
# Angle sumX: '1063397789000.0', Angle sumY: '620270.0' with D3 = '0.0'.
# Angle sumX: '985292449000.0', Angle sumY: '614030.0' with D3 = '0.01'.
# Angle sumX: '911627067200.0', Angle sumY: '605840.0' with D3 = '0.02'.
# Angle sumX: '842434361800.0', Angle sumY: '598730.0' with D3 = '0.03'.
# Angle sumX: '775668423400.0', Angle sumY: '592470.0' with D3 = '0.04'.
# Angle sumX: '713274726100.0', Angle sumY: '584300.0' with D3 = '0.05'.
# Angle sumX: '654183277700.0', Angle sumY: '578990.0' with D3 = '0.06'.
# Angle sumX: '599863902100.0', Angle sumY: '570900.0' with D3 = '0.07'.
# Angle sumX: '548704806500.0', Angle sumY: '562760.0' with D3 = '0.08'.
# Angle sumX: '501010234100.0', Angle sumY: '556460.0' with D3 = '0.09'.
# Angle sumX: '457894250000.0', Angle sumY: '549340.0' with D3 = '0.1'.
# Angle sumX: '417895478800.0', Angle sumY: '541220.0' with D3 = '0.11'.
# Angle sumX: '381705768200.0', Angle sumY: '534890.0' with D3 = '0.12'.
# Angle sumX: '349775448500.0', Angle sumY: '528620.0' with D3 = '0.13'.
# Angle sumX: '320858939300.0', Angle sumY: '519680.0' with D3 = '0.14'.
# Angle sumX: '296243353800.0', Angle sumY: '513330.0' with D3 = '0.15'.
# Angle sumX: '274743392900.0', Angle sumY: '505250.0' with D3 = '0.16'.
# Angle sumX: '257596938041.0', Angle sumY: '498140.0' with D3 = '0.17'.
# Angle sumX: '244611019144.0', Angle sumY: '491770.0' with D3 = '0.18'.
# Angle sumX: '234104686484.0', Angle sumY: '483710.0' with D3 = '0.19'.
# Angle sumX: '229865552129.0', Angle sumY: '478180.0' with D3 = '0.2'.
# Angle sumX: '226803551201.0', Angle sumY: '470200.0' with D3 = '0.21'.
# Angle sumX: '227236341800.0', Angle sumY: '462170.0' with D3 = '0.22'.
# Angle sumX: '233812349200.0', Angle sumY: '455760.0' with D3 = '0.23'.
# Angle sumX: '242836749200.0', Angle sumY: '448640.0' with D3 = '0.24'.
# Angle sumX: '254140603300.0', Angle sumY: '440630.0' with D3 = '0.25'.
# Angle sumX: '272504996100.0', Angle sumY: '434190.0' with D3 = '0.26'.
# Angle sumX: '294797945000.0', Angle sumY: '427810.0' with D3 = '0.27'.
# Angle sumX: '314810191700.0', Angle sumY: '419090.0' with D3 = '0.28'.
# Angle sumX: '345037680500.0', Angle sumY: '412630.0' with D3 = '0.29'.
# Angle sumX: '374357282000.0', Angle sumY: '404660.0' with D3 = '0.3'.
# Angle sumX: '409257466600.0', Angle sumY: '397550.0' with D3 = '0.31'.
# Angle sumX: '451412213800.0', Angle sumY: '391070.0' with D3 = '0.32'.
# Angle sumX: '491432119300.0', Angle sumY: '383120.0' with D3 = '0.33'.
# Angle sumX: '544757293000.0', Angle sumY: '377370.0' with D3 = '0.34'.
# Angle sumX: '591601918100.0', Angle sumY: '369500.0' with D3 = '0.35000000000000003'.
# Angle sumX: '642265440500.0', Angle sumY: '361580.0' with D3 = '0.36'.
# Angle sumX: '704473484500.0', Angle sumY: '355060.0' with D3 = '0.37'.
# Angle sumX: '765630366100.0', Angle sumY: '347940.0' with D3 = '0.38'.
# Angle sumX: '826883291200.0', Angle sumY: '340040.0' with D3 = '0.39'.
# Angle sumX: '901163244200.0', Angle sumY: '333490.0' with D3 = '0.4'.
# Angle sumX: '979042176900.0', Angle sumY: '327000.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1045254500000.0', Angle sumY: '318500.0' with D3 = '0.42'.
# Angle sumX: '1131792734900.0', Angle sumY: '311930.0' with D3 = '0.43'.
# Angle sumX: '1210553324900.0', Angle sumY: '304070.0' with D3 = '0.44'.
# Angle sumX: '1297305401600.0', Angle sumY: '296960.0' with D3 = '0.45'.
# Angle sumX: '1396026826900.0', Angle sumY: '290370.0' with D3 = '0.46'.
# Angle sumX: '1485233450900.0', Angle sumY: '282530.0' with D3 = '0.47000000000000003'.
# Angle sumX: '1598994643600.0', Angle sumY: '276560.0' with D3 = '0.48'.
# Angle sumX: '1694310400000.0', Angle sumY: '268800.0' with D3 = '0.49'.
# Running D2 = '0.12'...
# Angle sumX: '1026304098100.0', Angle sumY: '576410.0' with D3 = '0.0'.
# Angle sumX: '945688682500.0', Angle sumY: '566600.0' with D3 = '0.01'.
# Angle sumX: '869717070500.0', Angle sumY: '557920.0' with D3 = '0.02'.
# Angle sumX: '796108306500.0', Angle sumY: '550080.0' with D3 = '0.03'.
# Angle sumX: '727365704400.0', Angle sumY: '540300.0' with D3 = '0.04'.
# Angle sumX: '661654093000.0', Angle sumY: '533430.0' with D3 = '0.05'.
# Angle sumX: '601407512500.0', Angle sumY: '523740.0' with D3 = '0.06'.
# Angle sumX: '544460668200.0', Angle sumY: '513990.0' with D3 = '0.07'.
# Angle sumX: '490809634900.0', Angle sumY: '506100.0' with D3 = '0.08'.
# Angle sumX: '442197703700.0', Angle sumY: '497410.0' with D3 = '0.09'.
# Angle sumX: '396992884900.0', Angle sumY: '487680.0' with D3 = '0.1'.
# Angle sumX: '355379480100.0', Angle sumY: '479760.0' with D3 = '0.11'.
# Angle sumX: '318241858100.0', Angle sumY: '471910.0' with D3 = '0.12'.
# Angle sumX: '284943787300.0', Angle sumY: '461370.0' with D3 = '0.13'.
# Angle sumX: '255434724000.0', Angle sumY: '453420.0' with D3 = '0.14'.
# Angle sumX: '229700407400.0', Angle sumY: '443750.0' with D3 = '0.15'.
# Angle sumX: '208323963700.0', Angle sumY: '435060.0' with D3 = '0.16'.
# Angle sumX: '190993967684.0', Angle sumY: '427090.0' with D3 = '0.17'.
# Angle sumX: '176816311204.0', Angle sumY: '417440.0' with D3 = '0.18'.
# Angle sumX: '168359667751.04', Angle sumY: '410300.0' with D3 = '0.19'.
# Angle sumX: '162038109725.0', Angle sumY: '400750.0' with D3 = '0.2'.
# Angle sumX: '159361893800.0', Angle sumY: '391130.0' with D3 = '0.21'.
# Angle sumX: '162500940200.0', Angle sumY: '383110.0' with D3 = '0.22'.
# Angle sumX: '168575098100.0', Angle sumY: '374410.0' with D3 = '0.23'.
# Angle sumX: '177336548000.0', Angle sumY: '364820.0' with D3 = '0.24'.
# Angle sumX: '192820832900.0', Angle sumY: '356770.0' with D3 = '0.25'.
# Angle sumX: '212429178400.0', Angle sumY: '348780.0' with D3 = '0.26'.
# Angle sumX: '230733660100.0', Angle sumY: '338510.0' with D3 = '0.27'.
# Angle sumX: '258628081300.0', Angle sumY: '330430.0' with D3 = '0.28'.
# Angle sumX: '286342760500.0', Angle sumY: '320890.0' with D3 = '0.29'.
# Angle sumX: '319570497000.0', Angle sumY: '312210.0' with D3 = '0.3'.
# Angle sumX: '359941618900.0', Angle sumY: '304100.0' with D3 = '0.31'.
# Angle sumX: '398911892500.0', Angle sumY: '294580.0' with D3 = '0.32'.
# Angle sumX: '450581510800.0', Angle sumY: '287180.0' with D3 = '0.33'.
# Angle sumX: '496743635200.0', Angle sumY: '277760.0' with D3 = '0.34'.
# Angle sumX: '546896515400.0', Angle sumY: '268270.0' with D3 = '0.35000000000000003'.
# Angle sumX: '608249774600.0', Angle sumY: '260110.0' with D3 = '0.36'.
# Angle sumX: '669025172000.0', Angle sumY: '251420.0' with D3 = '0.37'.
# Angle sumX: '730321586000.0', Angle sumY: '241960.0' with D3 = '0.38'.
# Angle sumX: '804331994000.0', Angle sumY: '233780.0' with D3 = '0.39'.
# Angle sumX: '882119325600.0', Angle sumY: '225660.0' with D3 = '0.4'.
# Angle sumX: '949180243700.0', Angle sumY: '215660.0' with D3 = '0.41000000000000003'.
# Angle sumX: '1035884170000.0', Angle sumY: '207440.0' with D3 = '0.42'.
# Angle sumX: '1115622130900.0', Angle sumY: '198030.0' with D3 = '0.43'.
# Angle sumX: '1203549782500.0', Angle sumY: '189350.0' with D3 = '0.44'.
# Angle sumX: '1302926210000.0', Angle sumY: '181100.0' with D3 = '0.45'.
# Angle sumX: '1393711758400.0', Angle sumY: '171720.0' with D3 = '0.46'.
# Angle sumX: '1508248093600.0', Angle sumY: '164060.0' with D3 = '0.47000000000000003'.
# Angle sumX: '1605511512900.0', Angle sumY: '154770.0' with D3 = '0.48'.
# Angle sumX: '1706986628100.0', Angle sumY: '145410.0' with D3 = '0.49'.
# Running D2 = '0.13'...
# Angle sumX: '994800725000.0', Angle sumY: '530090.0' with D3 = '0.0'.
# Angle sumX: '911877914000.0', Angle sumY: '519820.0' with D3 = '0.01'.
# Angle sumX: '831252884500.0', Angle sumY: '510380.0' with D3 = '0.02'.
# Angle sumX: '755976284100.0', Angle sumY: '498960.0' with D3 = '0.03'.
# ...
# Angle sumX: '15157966610000.0', Angle sumY: '-3461000.0' with D3 = '0.43'.
# Angle sumX: '15807141650000.0', Angle sumY: '-3520600.0' with D3 = '0.44'.
# Angle sumX: '16522574850000.0', Angle sumY: '-3582600.0' with D3 = '0.45'.
# Angle sumX: '17219552660000.0', Angle sumY: '-3642500.0' with D3 = '0.46'.
# Angle sumX: '17915097610000.0', Angle sumY: '-3702000.0' with D3 = '0.47000000000000003'.
# Angle sumX: '18685251650000.0', Angle sumY: '-3764200.0' with D3 = '0.48'.
# Angle sumX: '19468161290000.0', Angle sumY: '-3826000.0' with D3 = '0.49'.
# Running D2 = '0.46'...
# Angle sumX: '2164893707600.0', Angle sumY: '-899740.0' with D3 = '0.0'.
# Angle sumX: '2131364897600.0', Angle sumY: '-963760.0' with D3 = '0.01'.
# Angle sumX: '2101455410000.0', Angle sumY: '-1024600.0' with D3 = '0.02'.
# Angle sumX: '2095570408900.0', Angle sumY: '-1086000.0' with D3 = '0.03'.
# Angle sumX: '2113871688400.0', Angle sumY: '-1149900.0' with D3 = '0.04'.
# Angle sumX: '2136139212500.0', Angle sumY: '-1210900.0' with D3 = '0.05'.
# Angle sumX: '2175573067600.0', Angle sumY: '-1271400.0' with D3 = '0.06'.
# Angle sumX: '2251193779600.0', Angle sumY: '-1336000.0' with D3 = '0.07'.
# Angle sumX: '2325977800000.0', Angle sumY: '-1397200.0' with D3 = '0.08'.
# Angle sumX: '2429571307600.0', Angle sumY: '-1460600.0' with D3 = '0.09'.
# Angle sumX: '2543364410000.0', Angle sumY: '-1522100.0' with D3 = '0.1'.
# Angle sumX: '2670654482500.0', Angle sumY: '-1583400.0' with D3 = '0.11'.
# Angle sumX: '2825459650000.0', Angle sumY: '-1646700.0' with D3 = '0.12'.
# Angle sumX: '2983617390100.0', Angle sumY: '-1707100.0' with D3 = '0.13'.
# Angle sumX: '3170765380000.0', Angle sumY: '-1769700.0' with D3 = '0.14'.
# Angle sumX: '3376196531600.0', Angle sumY: '-1832800.0' with D3 = '0.15'.
# Angle sumX: '3592939722041.0', Angle sumY: '-1894600.0' with D3 = '0.16'.
# Angle sumX: '3826031173682.49', Angle sumY: '-1956000.0' with D3 = '0.17'.
# Angle sumX: '4081782410329.0', Angle sumY: '-2018900.0' with D3 = '0.18'.
# Angle sumX: '4352191120400.0', Angle sumY: '-2080900.0' with D3 = '0.19'.
# Angle sumX: '4637880094900.0', Angle sumY: '-2142300.0' with D3 = '0.2'.
# Angle sumX: '4942215912400.0', Angle sumY: '-2205000.0' with D3 = '0.21'.
# Angle sumX: '5266597420900.0', Angle sumY: '-2267200.0' with D3 = '0.22'.
# Angle sumX: '5605400458400.0', Angle sumY: '-2329700.0' with D3 = '0.23'.
# Angle sumX: '5957498411600.0', Angle sumY: '-2391100.0' with D3 = '0.24'.
# Angle sumX: '6336158506400.0', Angle sumY: '-2453500.0' with D3 = '0.25'.
# Angle sumX: '6724437889600.0', Angle sumY: '-2515800.0' with D3 = '0.26'.
# Angle sumX: '7142666272400.0', Angle sumY: '-2578100.0' with D3 = '0.27'.
# Angle sumX: '7560874376900.0', Angle sumY: '-2639800.0' with D3 = '0.28'.
# Angle sumX: '7998323860000.0', Angle sumY: '-2701900.0' with D3 = '0.29'.
# Angle sumX: '8468131049600.0', Angle sumY: '-2764600.0' with D3 = '0.3'.
# Angle sumX: '8940179822400.0', Angle sumY: '-2826000.0' with D3 = '0.31'.
# Angle sumX: '9427141760000.0', Angle sumY: '-2888000.0' with D3 = '0.32'.
# Angle sumX: '9951927970000.0', Angle sumY: '-2950900.0' with D3 = '0.33'.
# Angle sumX: '10490480650000.0', Angle sumY: '-3013200.0' with D3 = '0.34'.
# Angle sumX: '11010591450000.0', Angle sumY: '-3074100.0' with D3 = '0.35000000000000003'.
# Angle sumX: '11591030090000.0', Angle sumY: '-3137200.0' with D3 = '0.36'.
# Angle sumX: '12158310280000.0', Angle sumY: '-3198800.0' with D3 = '0.37'.
# Angle sumX: '12749131250000.0', Angle sumY: '-3260200.0' with D3 = '0.38'.
# Angle sumX: '13385022500000.0', Angle sumY: '-3323500.0' with D3 = '0.39'.
# Angle sumX: '14000616100000.0', Angle sumY: '-3384900.0' with D3 = '0.4'.
# Angle sumX: '14691519410000.0', Angle sumY: '-3449000.0' with D3 = '0.41000000000000003'.
# Angle sumX: '15334475600000.0', Angle sumY: '-3509800.0' with D3 = '0.42'.
# Angle sumX: '15997443250000.0', Angle sumY: '-3571000.0' with D3 = '0.43'.
# Angle sumX: '16727067250000.0', Angle sumY: '-3634600.0' with D3 = '0.44'.
# Angle sumX: '17437996960000.0', Angle sumY: '-3696000.0' with D3 = '0.45'.
# Angle sumX: '18149470970000.0', Angle sumY: '-3757100.0' with D3 = '0.46'.
# Angle sumX: '18935250100000.0', Angle sumY: '-3820900.0' with D3 = '0.47000000000000003'.
# Angle sumX: '19734052130000.0', Angle sumY: '-3884200.0' with D3 = '0.48'.
# Angle sumX: '20455591700000.0', Angle sumY: '-3943100.0' with D3 = '0.49'.
# Running D2 = '0.47000000000000003'...
# Angle sumX: '2296223453600.0', Angle sumY: '-952060.0' with D3 = '0.0'.
# Angle sumX: '2254659250000.0', Angle sumY: '-1014500.0' with D3 = '0.01'.
# Angle sumX: '2238250600000.0', Angle sumY: '-1077600.0' with D3 = '0.02'.
# Angle sumX: '2246968192500.0', Angle sumY: '-1143300.0' with D3 = '0.03'.
# Angle sumX: '2259449779600.0', Angle sumY: '-1205900.0' with D3 = '0.04'.
# Angle sumX: '2289819188900.0', Angle sumY: '-1268000.0' with D3 = '0.05'.
# Angle sumX: '2358520650400.0', Angle sumY: '-1334500.0' with D3 = '0.06'.
# Angle sumX: '2425419842900.0', Angle sumY: '-1397300.0' with D3 = '0.07'.
# Angle sumX: '2523214456100.0', Angle sumY: '-1462600.0' with D3 = '0.08'.
# Angle sumX: '2630898826400.0', Angle sumY: '-1525700.0' with D3 = '0.09'.
# Angle sumX: '2752547300000.0', Angle sumY: '-1588700.0' with D3 = '0.1'.
# Angle sumX: '2903367707600.0', Angle sumY: '-1653800.0' with D3 = '0.11'.
# Angle sumX: '3056220292500.0', Angle sumY: '-1715700.0' with D3 = '0.12'.
# Angle sumX: '3240832150900.0', Angle sumY: '-1780100.0' with D3 = '0.13'.
# Angle sumX: '3444353672400.0', Angle sumY: '-1845000.0' with D3 = '0.14'.
# Angle sumX: '3657998010400.0', Angle sumY: '-1908300.0' with D3 = '0.15'.
# Angle sumX: '3890275219409.0', Angle sumY: '-1971500.0' with D3 = '0.16'.
# Angle sumX: '4146184601376.89', Angle sumY: '-2036200.0' with D3 = '0.17'.
# Angle sumX: '4415819252816.0', Angle sumY: '-2099800.0' with D3 = '0.18'.
# Angle sumX: '4701426000400.0', Angle sumY: '-2162800.0' with D3 = '0.19'.
# Angle sumX: '5008856562500.0', Angle sumY: '-2227400.0' with D3 = '0.2'.
# Angle sumX: '5334412352900.0', Angle sumY: '-2291200.0' with D3 = '0.21'.
# Angle sumX: '5676809306900.0', Angle sumY: '-2355500.0' with D3 = '0.22'.
# Angle sumX: '6032365110400.0', Angle sumY: '-2418600.0' with D3 = '0.23'.
# Angle sumX: '6414163499600.0', Angle sumY: '-2482600.0' with D3 = '0.24'.
# Angle sumX: '6808077730000.0', Angle sumY: '-2546700.0' with D3 = '0.25'.
# Angle sumX: '7230354850000.0', Angle sumY: '-2610600.0' with D3 = '0.26'.
# Angle sumX: '7655072040100.0', Angle sumY: '-2674000.0' with D3 = '0.27'.
# Angle sumX: '8100198427600.0', Angle sumY: '-2737900.0' with D3 = '0.28'.
# Angle sumX: '8576423723600.0', Angle sumY: '-2802200.0' with D3 = '0.29'.
# Angle sumX: '9057119572100.0', Angle sumY: '-2865400.0' with D3 = '0.3'.
# Angle sumX: '9553144498900.0', Angle sumY: '-2929100.0' with D3 = '0.31'.
# Angle sumX: '10086513320000.0', Angle sumY: '-2993600.0' with D3 = '0.32'.
# Angle sumX: '10635258500000.0', Angle sumY: '-3057700.0' with D3 = '0.33'.
# Angle sumX: '11166927300000.0', Angle sumY: '-3120300.0' with D3 = '0.34'.
# Angle sumX: '11757633040000.0', Angle sumY: '-3185000.0' with D3 = '0.35000000000000003'.
# Angle sumX: '12338067520000.0', Angle sumY: '-3248400.0' with D3 = '0.36'.
# Angle sumX: '12941462500000.0', Angle sumY: '-3311500.0' with D3 = '0.37'.
# Angle sumX: '13589885000000.0', Angle sumY: '-3376400.0' with D3 = '0.38'.
# Angle sumX: '14220654970000.0', Angle sumY: '-3439600.0' with D3 = '0.39'.
# Angle sumX: '14925854800000.0', Angle sumY: '-3505400.0' with D3 = '0.4'.
# Angle sumX: '15583269200000.0', Angle sumY: '-3567800.0' with D3 = '0.41000000000000003'.
# Angle sumX: '16263786730000.0', Angle sumY: '-3630800.0' with D3 = '0.42'.
# Angle sumX: '17009689220000.0', Angle sumY: '-3696100.0' with D3 = '0.43'.
# Angle sumX: '17738165450000.0', Angle sumY: '-3759200.0' with D3 = '0.44'.
# Angle sumX: '18467730090000.0', Angle sumY: '-3822000.0' with D3 = '0.45'.
# Angle sumX: '19272216500000.0', Angle sumY: '-3887500.0' with D3 = '0.46'.
# Angle sumX: '20089983940000.0', Angle sumY: '-3952500.0' with D3 = '0.47000000000000003'.
# Angle sumX: '20832919880000.0', Angle sumY: '-4013200.0' with D3 = '0.48'.
# Angle sumX: '21695876020000.0', Angle sumY: '-4078900.0' with D3 = '0.49'.
# Running D2 = '0.48'...
# Angle sumX: '2386046836900.0', Angle sumY: '-990630.0' with D3 = '0.0'.
# Angle sumX: '2357775250000.0', Angle sumY: '-1055300.0' with D3 = '0.01'.
# Angle sumX: '2354749940000.0', Angle sumY: '-1122500.0' with D3 = '0.02'.
# Angle sumX: '2355741280100.0', Angle sumY: '-1186600.0' with D3 = '0.03'.
# Angle sumX: '2375145778900.0', Angle sumY: '-1250100.0' with D3 = '0.04'.
# Angle sumX: '2434425412900.0', Angle sumY: '-1318200.0' with D3 = '0.05'.
# Angle sumX: '2491630254100.0', Angle sumY: '-1382500.0' with D3 = '0.06'.
# Angle sumX: '2581023220100.0', Angle sumY: '-1449400.0' with D3 = '0.07'.
# Angle sumX: '2680574240000.0', Angle sumY: '-1514000.0' with D3 = '0.08'.
# Angle sumX: '2793912563600.0', Angle sumY: '-1578400.0' with D3 = '0.09'.
# Angle sumX: '2938167370900.0', Angle sumY: '-1645100.0' with D3 = '0.1'.
# Angle sumX: '3083580259600.0', Angle sumY: '-1708400.0' with D3 = '0.11'.
# Angle sumX: '3262962548900.0', Angle sumY: '-1774400.0' with D3 = '0.12'.
# Angle sumX: '3461412243600.0', Angle sumY: '-1840800.0' with D3 = '0.13'.
# Angle sumX: '3669911820900.0', Angle sumY: '-1905600.0' with D3 = '0.14'.
# Angle sumX: '3898109650000.0', Angle sumY: '-1970300.0' with D3 = '0.15'.
# Angle sumX: '4150743744464.0', Angle sumY: '-2036500.0' with D3 = '0.16'.
# Angle sumX: '4416955244516.0', Angle sumY: '-2101600.0' with D3 = '0.17'.
# Angle sumX: '4699792812244.0', Angle sumY: '-2166100.0' with D3 = '0.18'.
# Angle sumX: '5006612086900.0', Angle sumY: '-2232300.0' with D3 = '0.19'.
# Angle sumX: '5330026170400.0', Angle sumY: '-2297500.0' with D3 = '0.2'.
# Angle sumX: '5672596082500.0', Angle sumY: '-2363400.0' with D3 = '0.21'.
# Angle sumX: '6028160915600.0', Angle sumY: '-2428000.0' with D3 = '0.22'.
# Angle sumX: '6409510024100.0', Angle sumY: '-2493400.0' with D3 = '0.23'.
# Angle sumX: '6805423642100.0', Angle sumY: '-2559100.0' with D3 = '0.24'.
# Angle sumX: '7227982620900.0', Angle sumY: '-2624400.0' with D3 = '0.25'.
# Angle sumX: '7655944553600.0', Angle sumY: '-2689400.0' with D3 = '0.26'.
# Angle sumX: '8104332166400.0', Angle sumY: '-2754800.0' with D3 = '0.27'.
# Angle sumX: '8584071934100.0', Angle sumY: '-2820700.0' with D3 = '0.28'.
# Angle sumX: '9068275955600.0', Angle sumY: '-2885300.0' with D3 = '0.29'.
# Angle sumX: '9569917662500.0', Angle sumY: '-2950600.0' with D3 = '0.3'.
# Angle sumX: '10107891560000.0', Angle sumY: '-3016600.0' with D3 = '0.31'.
# Angle sumX: '10661424410000.0', Angle sumY: '-3082100.0' with D3 = '0.32'.
# Angle sumX: '11201084690000.0', Angle sumY: '-3146300.0' with D3 = '0.33'.
# Angle sumX: '11798082740000.0', Angle sumY: '-3212500.0' with D3 = '0.34'.
# Angle sumX: '12386670050000.0', Angle sumY: '-3277400.0' with D3 = '0.35000000000000003'.
# Angle sumX: '12998220250000.0', Angle sumY: '-3342000.0' with D3 = '0.36'.
# Angle sumX: '13655628500000.0', Angle sumY: '-3408500.0' with D3 = '0.37'.
# Angle sumX: '14295057250000.0', Angle sumY: '-3473100.0' with D3 = '0.38'.
# Angle sumX: '15009390400000.0', Angle sumY: '-3540400.0' with D3 = '0.39'.
# Angle sumX: '15678676000000.0', Angle sumY: '-3604400.0' with D3 = '0.4'.
# Angle sumX: '16370580850000.0', Angle sumY: '-3668900.0' with D3 = '0.41000000000000003'.
# Angle sumX: '17127771700000.0', Angle sumY: '-3735700.0' with D3 = '0.42'.
# Angle sumX: '17868110900000.0', Angle sumY: '-3800300.0' with D3 = '0.43'.
# Angle sumX: '18611172450000.0', Angle sumY: '-3864600.0' with D3 = '0.44'.
# Angle sumX: '19428730400000.0', Angle sumY: '-3931600.0' with D3 = '0.45'.
# Angle sumX: '20260186900000.0', Angle sumY: '-3998100.0' with D3 = '0.46'.
# Angle sumX: '21017825530000.0', Angle sumY: '-4060300.0' with D3 = '0.47000000000000003'.
# Angle sumX: '21896076500000.0', Angle sumY: '-4127500.0' with D3 = '0.48'.
# Angle sumX: '22723458320000.0', Angle sumY: '-4191400.0' with D3 = '0.49'.
# Running D2 = '0.49'...
# Angle sumX: '2485342250000.0', Angle sumY: '-1030000.0' with D3 = '0.0'.
# Angle sumX: '2469838400000.0', Angle sumY: '-1098800.0' with D3 = '0.01'.
# Angle sumX: '2458514530000.0', Angle sumY: '-1164300.0' with D3 = '0.02'.
# Angle sumX: '2466262948100.0', Angle sumY: '-1229200.0' with D3 = '0.03'.
# Angle sumX: '2515573801600.0', Angle sumY: '-1299000.0' with D3 = '0.04'.
# Angle sumX: '2562037963600.0', Angle sumY: '-1364700.0' with D3 = '0.05'.
# Angle sumX: '2642228526400.0', Angle sumY: '-1433200.0' with D3 = '0.06'.
# Angle sumX: '2732615384900.0', Angle sumY: '-1499200.0' with D3 = '0.07'.
# Angle sumX: '2837218579600.0', Angle sumY: '-1565100.0' with D3 = '0.08'.
# Angle sumX: '2974158582400.0', Angle sumY: '-1633400.0' with D3 = '0.09'.
# Angle sumX: '3111086116900.0', Angle sumY: '-1698000.0' with D3 = '0.1'.
# Angle sumX: '3284140395600.0', Angle sumY: '-1765500.0' with D3 = '0.11'.
# Angle sumX: '3477125134100.0', Angle sumY: '-1833500.0' with D3 = '0.12'.
# Angle sumX: '3679778088100.0', Angle sumY: '-1899800.0' with D3 = '0.13'.
# Angle sumX: '3902803411600.0', Angle sumY: '-1965900.0' with D3 = '0.14'.
# Angle sumX: '4151839422100.0', Angle sumY: '-2033700.0' with D3 = '0.15'.
# Angle sumX: '4413522140521.0', Angle sumY: '-2100200.0' with D3 = '0.16'.
# Angle sumX: '4692904242500.0', Angle sumY: '-2166200.0' with D3 = '0.17'.
# Angle sumX: '4997964410036.0', Angle sumY: '-2233900.0' with D3 = '0.18'.
# Angle sumX: '5319007600100.0', Angle sumY: '-2300600.0' with D3 = '0.19'.
# Angle sumX: '5661078582100.0', Angle sumY: '-2368100.0' with D3 = '0.2'.
# Angle sumX: '6015504020000.0', Angle sumY: '-2434100.0' with D3 = '0.21'.
# Angle sumX: '6396234156100.0', Angle sumY: '-2501000.0' with D3 = '0.22'.
# Angle sumX: '6793487414100.0', Angle sumY: '-2568300.0' with D3 = '0.23'.
# Angle sumX: '7215698560100.0', Angle sumY: '-2635000.0' with D3 = '0.24'.
# Angle sumX: '7645201912100.0', Angle sumY: '-2701400.0' with D3 = '0.25'.
# Angle sumX: '8096765712400.0', Angle sumY: '-2768400.0' with D3 = '0.26'.
# Angle sumX: '8578278269600.0', Angle sumY: '-2835700.0' with D3 = '0.27'.
# Angle sumX: '9065910868100.0', Angle sumY: '-2901800.0' with D3 = '0.28'.
# Angle sumX: '9571958776400.0', Angle sumY: '-2968600.0' with D3 = '0.29'.
# Angle sumX: '10114068365600.0', Angle sumY: '-3036100.0' with D3 = '0.3'.
# Angle sumX: '10672283300000.0', Angle sumY: '-3103100.0' with D3 = '0.31'.
# Angle sumX: '11218518440000.0', Angle sumY: '-3168800.0' with D3 = '0.32'.
# Angle sumX: '11821692500000.0', Angle sumY: '-3236500.0' with D3 = '0.33'.
# Angle sumX: '12418038610000.0', Angle sumY: '-3303000.0' with D3 = '0.34'.
# Angle sumX: '13036522960000.0', Angle sumY: '-3369000.0' with D3 = '0.35000000000000003'.
# Angle sumX: '13700982100000.0', Angle sumY: '-3436900.0' with D3 = '0.36'.
# Angle sumX: '14350208500000.0', Angle sumY: '-3503100.0' with D3 = '0.37'.
# Angle sumX: '15072823300000.0', Angle sumY: '-3571900.0' with D3 = '0.38'.
# Angle sumX: '15752012900000.0', Angle sumY: '-3637300.0' with D3 = '0.39'.
# Angle sumX: '16454448980000.0', Angle sumY: '-3703300.0' with D3 = '0.4'.
# Angle sumX: '17222366250000.0', Angle sumY: '-3771600.0' with D3 = '0.41000000000000003'.
# Angle sumX: '17974784900000.0', Angle sumY: '-3837700.0' with D3 = '0.42'.
# Angle sumX: '18730473250000.0', Angle sumY: '-3903500.0' with D3 = '0.43'.
# Angle sumX: '19560198010000.0', Angle sumY: '-3972000.0' with D3 = '0.44'.
# Angle sumX: '20404828490000.0', Angle sumY: '-4040000.0' with D3 = '0.45'.
# Angle sumX: '21177576450000.0', Angle sumY: '-4103700.0' with D3 = '0.46'.
# Angle sumX: '22069770970000.0', Angle sumY: '-4172400.0' with D3 = '0.47000000000000003'.
# Angle sumX: '22912689330000.0', Angle sumY: '-4237800.0' with D3 = '0.48'.
# Angle sumX: '23796089650000.0', Angle sumY: '-4303900.0' with D3 = '0.49'.
# finished it
# Finished loop
# Best setup for focusing in the x direction: '[0.1, 0.18, 0.18, 700000000.0]'.
# Best setup for focusing in the y direction: '[0.1, 0.15, 0.33, 700000000.0]'.
# Running best setup again to get full data.
# Running best setup again to get full data.

# %%
def func(D):

    D1 = 0.1
    mom = 7.0E+8
    
    dataCurrent = runRef(D1, D[0], D[1], mom, False)
    sumX = angleCalculationX(dataCurrent)

    return sumX

# %%
def findGlobalMin():

    
    Dguess = [0.1, 0.3]
    
    Dmin = [0.0,0.0]
    Dmax = [0.5,0.5]
    
    bounds = [(low, high) for low, high in zip(Dmin, Dmax)]

    minimizer_kwargs = dict(method="L-BFGS-B", bounds=bounds)
    res = sc.optimize.basinhopping(func, Dguess, minimizer_kwargs=minimizer_kwargs)


    #bnds = ((0., 0.5), (0, 0.5))
    #res = optimize.minimize(func, (0.1, 0.2), method='TNC', bounds=bnds, tol=1e-10)
    
    plotRefXY(0.1, *res, 7.0E+8)
    
    print(res)

    return

# %%
findGlobalMin()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 findGlobalMin()
#
# Cell In[34], line 12, in findGlobalMin()
#       9 bounds = [(low, high) for low, high in zip(Dmin, Dmax)]
#      11 minimizer_kwargs = dict(method="L-BFGS-B", bounds=bounds)
# ---> 12 res = sc.optimize.basinhopping(func, Dguess, minimizer_kwargs=minimizer_kwargs)
#      15 #bnds = ((0., 0.5), (0, 0.5))
#      16 #res = optimize.minimize(func, (0.1, 0.2), method='TNC', bounds=bnds, tol=1e-10)
#      18 plotRefXY(0.1, *res, 7.0E+8)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_basinhopping.py:714, in basinhopping(func, x0, niter, T, stepsize, minimizer_kwargs, take_step, accept_test, callback, interval, disp, niter_success, seed, target_accept_rate, stepwise_factor)
#     711 if niter_success is None:
#     712     niter_success = niter + 2
# --> 714 bh = BasinHoppingRunner(x0, wrapped_minimizer, take_step_wrapped,
#     715                         accept_tests, disp=disp)
#     717 # The wrapped minimizer is called once during construction of
#     718 # BasinHoppingRunner, so run the callback
#     719 if callable(callback):
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_basinhopping.py:78, in BasinHoppingRunner.__init__(self, x0, minimizer, step_taking, accept_tests, disp)
#      75 self.res.minimization_failures = 0
#      77 # do initial minimization
# ---> 78 minres = minimizer(self.x)
#      79 if not minres.success:
#      80     self.res.minimization_failures += 1
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_basinhopping.py:303, in MinimizerWrapper.__call__(self, x0)
#     301     return self.minimizer(x0, **self.kwargs)
#     302 else:
# --> 303     return self.minimizer(self.func, x0, **self.kwargs)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_minimize.py:710, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     707     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     708                              **options)
#     709 elif meth == 'l-bfgs-b':
# --> 710     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     711                            callback=callback, **options)
#     712 elif meth == 'tnc':
#     713     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     714                         **options)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:307, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     304     else:
#     305         iprint = disp
# --> 307 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     308                               bounds=new_bounds,
#     309                               finite_diff_rel_step=finite_diff_rel_step)
#     311 func_and_grad = sf.fun_and_grad
#     313 fortran_int = _lbfgsb.types.intvar.dtype
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_optimize.py:383, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     379     bounds = (-np.inf, np.inf)
#     381 # ScalarFunction caches. Reuse of fun(x) during grad
#     382 # calculation reduces overall function evaluations.
# --> 383 sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     386 return sf
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/.local/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# TypeError: func() missing 1 required positional argument: 'D3'

# %%
plotRefXY(0.1, 0.17679, 0.1859,7E+8)
# Out:
# Running best setup again to get full data.

# %%
plotSumData("X")
plotSumData("Y")

# %%
plotDSum("D1")
plotDSum("D2")
plotDSum("D3")

# %%
def runBeam(D1,D2,D3, moreData):

    #change setup according to arguments  
    Q1pos = D1 + lengthQ1/2 + 3*boreQ1
    Q2pos = D1 + lengthQ1 + D2 + lengthQ2/2 + 6*boreQ1 + 3*boreQ2
    Q3pos = D1 + lengthQ1 + D2 + lengthQ2 + D3 + lengthQ3/2 + 6*boreQ1 + 6*boreQ2 + 3*boreQ3

    changeInputData("Q_pos(1)",str(Q1pos))
    changeInputData("Q_pos(2)",str(Q2pos) )
    changeInputData("Q_pos(3)",str(Q3pos) )


    
    subprocess.run("source /opt/intel/oneapi/setvars.sh > out.txt && ./Astra " + fileName + " >> output.txt" , shell=True,check=True,executable='/bin/bash' )

    #condition for 0. ref particle-> it cannot move
    with open(fileName + ".ref." + fillNumber,"r") as refFile:
        refData = refFile.readlines()
        
    if not (isRef0Straight(refData[-1][7], refData[-1][8]) and isRef0Straight(refData[-1][5], refData[-1][6])):
        print(f"Reference 0 particle with 0 offset and 0 angle moved in setup with D1 = '{D1}', D2 = '{D2}' and D3 = '{D3}'.")
        return 1
        
    #load beam data
    with open(fileName + ".Xemit." + fillNumber,"r") as fileX:
        xBeamData = fileX.readlines()
    xDivergence = float(xBeamData[-1][4])
        
    with open(fileName + ".Yemit." + fillNumber,"r") as fileY:
        yBeamData = fileY.readlines()
    yDivergence = float(yBeamData[-1][4])

    #here implement more conditions when each condition has it's own weight. For example on the diameter of the beam or longitudinal width

    
    sum = math.sqrt( xDivergence**2 + yDivergence**2)


    return sum

# %%
def Beam():
# function which each setup runs only once and looks at the outcome of all 
    update()

    #3 different variables- D1, D2, D3
    D1 = []
    D2 = []
    D3 = []

    #1/4 of the setup length will be divided into nIntervals
    interval = setupLength/(10*nIntervals)
    
    for i in range(nIntervals):
        D1.append(i*interval)
        D2.append(i*interval)
        D3.append(i*interval)
    
    bestD = [1,2,3] 
    minSum = 1e+7 #initial guess of sum of angles in x,y directions
    
    #3 cycles which run through all ranges of D1, D2, D3
    for D1_current in D1:
        print(f"Running D1 = '{D1_current}'... ")
        for D2_current in D2:
            for D3_current in D3:
                sum = runBeam(D1_current, D2_current, D3_current, False)
                if sum == 1:
                    continue
                #print(f"Momentum sum: '{momSum}'.")
                if sum <= minSum:
                    minSum = sum
                    bestD = {D1_current, D2_current, D3_current}
                    #print(f"Found a new temporary best setup with D1 = '{D1_current}', D2 = '{D2_current}', D3 = '{D3_current}'")

        print(f"finished it")
    
    print(f"Finished loop for beam")

    return bestD

# %%
def plotBeam():
    #function that plots output of beam
    #what to plot?!

    





    return

# %%
bestBeamD = Beam()
plotBeam(*bestBeamD)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 bestBeamD = Beam()
#       2 plotBeam(*bestBeamD)
#
# NameError: name 'Beam' is not defined
